# %%
import gym, gym_unbalanced_disk, time
import numpy as np
from stable_baselines3 import PPO

# %%
reward_fun = lambda self: np.exp(-(self.th%(2*np.pi)-np.pi)**2/(2*(np.pi/7)**2)) #example reward function, change this!
env = gym.make('unbalanced-disk-v0', dt=0.025, umax=3., reward_fun=reward_fun) 

model = PPO('MlpPolicy', env, verbose=1) #b)
model.learn(total_timesteps=100_000)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 0        |
# | time/              |          |
# |    fps             | 146      |
# |    iterations      | 1        |
# |    time_elapsed    | 13       |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 0            |
# | time/                   |              |
# |    fps                  | 127          |
# |    iterations           | 2            |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0025483952 |
# |    clip_fraction        | 0.0172       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -24.1        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0151       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0035      |
# |    std                  | 0.983        |
# |    value_loss           | 0.00707      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 0            |
# | time/                   |              |
# |    fps                  | 119          |
# |    iterations           | 3            |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0065232157 |
# |    clip_fraction        | 0.0396       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | -7.7         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0192      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00557     |
# |    std                  | 0.971        |
# |    value_loss           | 0.00039      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 300        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 4          |
# |    time_elapsed         | 69         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.00938367 |
# |    clip_fraction        | 0.0939     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.4       |
# |    explained_variance   | -9.09      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.018     |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0105    |
# |    std                  | 0.989      |
# |    value_loss           | 1.3e-05    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 0            |
# | time/                   |              |
# |    fps                  | 116          |
# |    iterations           | 5            |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0052164746 |
# |    clip_fraction        | 0.0378       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -14.1        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.013       |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00321     |
# |    std                  | 1.01         |
# |    value_loss           | 7.5e-06      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 7.75e-07     |
# | time/                   |              |
# |    fps                  | 115          |
# |    iterations           | 6            |
# |    time_elapsed         | 106          |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0048358203 |
# |    clip_fraction        | 0.0214       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | -19.5        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0204      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00221     |
# |    std                  | 1.02         |
# |    value_loss           | 1.66e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 6.81e-07     |
# | time/                   |              |
# |    fps                  | 116          |
# |    iterations           | 7            |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0013129422 |
# |    clip_fraction        | 0.0162       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -28.8        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0112       |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.002       |
# |    std                  | 1.02         |
# |    value_loss           | 3.48e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 3.43e-06     |
# | time/                   |              |
# |    fps                  | 117          |
# |    iterations           | 8            |
# |    time_elapsed         | 139          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0062135276 |
# |    clip_fraction        | 0.0588       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -11.4        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0233       |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00543     |
# |    std                  | 1.02         |
# |    value_loss           | 1.37e-06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 0.00294      |
# | time/                   |              |
# |    fps                  | 118          |
# |    iterations           | 9            |
# |    time_elapsed         | 155          |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0038851092 |
# |    clip_fraction        | 0.0455       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | -34.6        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0166      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00324     |
# |    std                  | 1.01         |
# |    value_loss           | 1.26e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 0.00266     |
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 10          |
# |    time_elapsed         | 173         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.005054295 |
# |    clip_fraction        | 0.0371      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | -1.06       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00512    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00261    |
# |    std                  | 1           |
# |    value_loss           | 0.000124    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 0.0291      |
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 11          |
# |    time_elapsed         | 186         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.004923025 |
# |    clip_fraction        | 0.0561      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | -1.65       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0059      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00474    |
# |    std                  | 1.01        |
# |    value_loss           | 3.44e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 0.668        |
# | time/                   |              |
# |    fps                  | 124          |
# |    iterations           | 12           |
# |    time_elapsed         | 198          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0024017897 |
# |    clip_fraction        | 0.0162       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.0899       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0157      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00214     |
# |    std                  | 0.98         |
# |    value_loss           | 0.00284      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 0.825        |
# | time/                   |              |
# |    fps                  | 127          |
# |    iterations           | 13           |
# |    time_elapsed         | 209          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0051623224 |
# |    clip_fraction        | 0.0396       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.0381       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.699        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00436     |
# |    std                  | 0.96         |
# |    value_loss           | 1.45         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 2.02        |
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 14          |
# |    time_elapsed         | 222         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.004574933 |
# |    clip_fraction        | 0.075       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.338       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.246       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00622    |
# |    std                  | 0.956       |
# |    value_loss           | 0.354       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 4.14         |
# | time/                   |              |
# |    fps                  | 130          |
# |    iterations           | 15           |
# |    time_elapsed         | 234          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0023788086 |
# |    clip_fraction        | 0.0204       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.362        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.716        |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0027      |
# |    std                  | 0.954        |
# |    value_loss           | 2.52         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 6.47         |
# | time/                   |              |
# |    fps                  | 132          |
# |    iterations           | 16           |
# |    time_elapsed         | 247          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0050676125 |
# |    clip_fraction        | 0.04         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.508        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.56         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00464     |
# |    std                  | 0.95         |
# |    value_loss           | 3.88         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 8.67         |
# | time/                   |              |
# |    fps                  | 134          |
# |    iterations           | 17           |
# |    time_elapsed         | 258          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0019829986 |
# |    clip_fraction        | 0.0266       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.709        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.25         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0022      |
# |    std                  | 0.946        |
# |    value_loss           | 3.08         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 10.3         |
# | time/                   |              |
# |    fps                  | 136          |
# |    iterations           | 18           |
# |    time_elapsed         | 269          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0045106784 |
# |    clip_fraction        | 0.0354       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.534        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.4          |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00497     |
# |    std                  | 0.946        |
# |    value_loss           | 2.51         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 12.6        |
# | time/                   |             |
# |    fps                  | 138         |
# |    iterations           | 19          |
# |    time_elapsed         | 280         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.005637812 |
# |    clip_fraction        | 0.0536      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.713       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.472       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00784    |
# |    std                  | 0.942       |
# |    value_loss           | 1.62        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 14.5        |
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 20          |
# |    time_elapsed         | 293         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.004125406 |
# |    clip_fraction        | 0.039       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.694       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.53        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00526    |
# |    std                  | 0.94        |
# |    value_loss           | 2.89        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 16.3        |
# | time/                   |             |
# |    fps                  | 141         |
# |    iterations           | 21          |
# |    time_elapsed         | 303         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.004083592 |
# |    clip_fraction        | 0.0367      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.699       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.958       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00479    |
# |    std                  | 0.936       |
# |    value_loss           | 2.09        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 18.4         |
# | time/                   |              |
# |    fps                  | 143          |
# |    iterations           | 22           |
# |    time_elapsed         | 314          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0038505828 |
# |    clip_fraction        | 0.0284       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.817        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.911        |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00196     |
# |    std                  | 0.942        |
# |    value_loss           | 1.94         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 21.6        |
# | time/                   |             |
# |    fps                  | 145         |
# |    iterations           | 23          |
# |    time_elapsed         | 324         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.002684455 |
# |    clip_fraction        | 0.0303      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.787       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.75        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00293    |
# |    std                  | 0.936       |
# |    value_loss           | 3.15        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 24.2        |
# | time/                   |             |
# |    fps                  | 146         |
# |    iterations           | 24          |
# |    time_elapsed         | 334         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.004269013 |
# |    clip_fraction        | 0.0335      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.37        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.76        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00638    |
# |    std                  | 0.926       |
# |    value_loss           | 3.28        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 27.3         |
# | time/                   |              |
# |    fps                  | 148          |
# |    iterations           | 25           |
# |    time_elapsed         | 344          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0061249956 |
# |    clip_fraction        | 0.0539       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.272        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.92         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00506     |
# |    std                  | 0.925        |
# |    value_loss           | 5.35         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 30.3        |
# | time/                   |             |
# |    fps                  | 149         |
# |    iterations           | 26          |
# |    time_elapsed         | 355         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.005494831 |
# |    clip_fraction        | 0.038       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.612       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.09        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00398    |
# |    std                  | 0.918       |
# |    value_loss           | 2.47        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 33.7         |
# | time/                   |              |
# |    fps                  | 150          |
# |    iterations           | 27           |
# |    time_elapsed         | 366          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0027737047 |
# |    clip_fraction        | 0.0345       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.546        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.969        |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00236     |
# |    std                  | 0.922        |
# |    value_loss           | 3.82         |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 300       |
# |    ep_rew_mean          | 36.5      |
# | time/                   |           |
# |    fps                  | 152       |
# |    iterations           | 28        |
# |    time_elapsed         | 376       |
# |    total_timesteps      | 57344     |
# | train/                  |           |
# |    approx_kl            | 0.0024152 |
# |    clip_fraction        | 0.021     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.33     |
# |    explained_variance   | 0.37      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.53      |
# |    n_updates            | 270       |
# |    policy_gradient_loss | -0.00137  |
# |    std                  | 0.917     |
# |    value_loss           | 2.86      |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 38.2         |
# | time/                   |              |
# |    fps                  | 153          |
# |    iterations           | 29           |
# |    time_elapsed         | 387          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0030483776 |
# |    clip_fraction        | 0.0421       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.395        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.891        |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00192     |
# |    std                  | 0.915        |
# |    value_loss           | 2.02         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 39.8        |
# | time/                   |             |
# |    fps                  | 154         |
# |    iterations           | 30          |
# |    time_elapsed         | 397         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.004812163 |
# |    clip_fraction        | 0.0411      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.466       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.744       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00551    |
# |    std                  | 0.907       |
# |    value_loss           | 2.19        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 40.8        |
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 31          |
# |    time_elapsed         | 407         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.008388076 |
# |    clip_fraction        | 0.0525      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.542       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.1         |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00338    |
# |    std                  | 0.9         |
# |    value_loss           | 1.55        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 41.6         |
# | time/                   |              |
# |    fps                  | 156          |
# |    iterations           | 32           |
# |    time_elapsed         | 418          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0029687276 |
# |    clip_fraction        | 0.0324       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.301        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.48         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00105     |
# |    std                  | 0.902        |
# |    value_loss           | 2.55         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 43.9        |
# | time/                   |             |
# |    fps                  | 157         |
# |    iterations           | 33          |
# |    time_elapsed         | 427         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.005592989 |
# |    clip_fraction        | 0.0618      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.528       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.904       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00424    |
# |    std                  | 0.894       |
# |    value_loss           | 1.77        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 45          |
# | time/                   |             |
# |    fps                  | 158         |
# |    iterations           | 34          |
# |    time_elapsed         | 438         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.003226589 |
# |    clip_fraction        | 0.0219      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.154       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.78        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00125    |
# |    std                  | 0.897       |
# |    value_loss           | 1.9         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 46.8        |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 35          |
# |    time_elapsed         | 448         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.007596815 |
# |    clip_fraction        | 0.0777      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.473       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.867       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00385    |
# |    std                  | 0.897       |
# |    value_loss           | 1.39        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 48.6         |
# | time/                   |              |
# |    fps                  | 160          |
# |    iterations           | 36           |
# |    time_elapsed         | 458          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0037847306 |
# |    clip_fraction        | 0.037        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.321        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.521        |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00251     |
# |    std                  | 0.9          |
# |    value_loss           | 2.18         |
# ------------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 300      |
# |    ep_rew_mean          | 50.1     |
# | time/                   |          |
# |    fps                  | 161      |
# |    iterations           | 37       |
# |    time_elapsed         | 468      |
# |    total_timesteps      | 75776    |
# | train/                  |          |
# |    approx_kl            | 0.007874 |
# |    clip_fraction        | 0.0688   |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -1.32    |
# |    explained_variance   | 0.578    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.314    |
# |    n_updates            | 360      |
# |    policy_gradient_loss | -0.00585 |
# |    std                  | 0.907    |
# |    value_loss           | 1.51     |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 50.6        |
# | time/                   |             |
# |    fps                  | 162         |
# |    iterations           | 38          |
# |    time_elapsed         | 478         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.005193834 |
# |    clip_fraction        | 0.0458      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.323       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.827       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00272    |
# |    std                  | 0.899       |
# |    value_loss           | 1.59        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 51           |
# | time/                   |              |
# |    fps                  | 163          |
# |    iterations           | 39           |
# |    time_elapsed         | 489          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0063699796 |
# |    clip_fraction        | 0.0883       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.447        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.52         |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00691     |
# |    std                  | 0.883        |
# |    value_loss           | 1.52         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 52.3         |
# | time/                   |              |
# |    fps                  | 164          |
# |    iterations           | 40           |
# |    time_elapsed         | 499          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0046920725 |
# |    clip_fraction        | 0.0393       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | 0.461        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.927        |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00371     |
# |    std                  | 0.879        |
# |    value_loss           | 1.59         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 52.9        |
# | time/                   |             |
# |    fps                  | 164         |
# |    iterations           | 41          |
# |    time_elapsed         | 509         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.006324444 |
# |    clip_fraction        | 0.0515      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.326       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.13        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00321    |
# |    std                  | 0.881       |
# |    value_loss           | 2.05        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 53.4         |
# | time/                   |              |
# |    fps                  | 165          |
# |    iterations           | 42           |
# |    time_elapsed         | 519          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0048480425 |
# |    clip_fraction        | 0.0529       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.323        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.86         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00311     |
# |    std                  | 0.863        |
# |    value_loss           | 1.5          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 54.6        |
# | time/                   |             |
# |    fps                  | 166         |
# |    iterations           | 43          |
# |    time_elapsed         | 529         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.008303313 |
# |    clip_fraction        | 0.0383      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.437       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.823       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00223    |
# |    std                  | 0.853       |
# |    value_loss           | 1.73        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 55           |
# | time/                   |              |
# |    fps                  | 166          |
# |    iterations           | 44           |
# |    time_elapsed         | 540          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0064276913 |
# |    clip_fraction        | 0.0369       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.291        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.889        |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00177     |
# |    std                  | 0.84         |
# |    value_loss           | 2.1          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 55.7         |
# | time/                   |              |
# |    fps                  | 167          |
# |    iterations           | 45           |
# |    time_elapsed         | 550          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0034261397 |
# |    clip_fraction        | 0.0381       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.344        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.618        |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00147     |
# |    std                  | 0.83         |
# |    value_loss           | 1.76         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 56.6         |
# | time/                   |              |
# |    fps                  | 167          |
# |    iterations           | 46           |
# |    time_elapsed         | 561          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0042666253 |
# |    clip_fraction        | 0.0657       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.406        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.764        |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.0022      |
# |    std                  | 0.829        |
# |    value_loss           | 1.79         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 57.9         |
# | time/                   |              |
# |    fps                  | 168          |
# |    iterations           | 47           |
# |    time_elapsed         | 571          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0042934245 |
# |    clip_fraction        | 0.0431       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.567        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.992        |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00292     |
# |    std                  | 0.838        |
# |    value_loss           | 2.19         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 57.8         |
# | time/                   |              |
# |    fps                  | 169          |
# |    iterations           | 48           |
# |    time_elapsed         | 581          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0049984623 |
# |    clip_fraction        | 0.045        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.421        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.8          |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.0019      |
# |    std                  | 0.839        |
# |    value_loss           | 2.3          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 58.5        |
# | time/                   |             |
# |    fps                  | 169         |
# |    iterations           | 49          |
# |    time_elapsed         | 591         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.004580182 |
# |    clip_fraction        | 0.0451      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.519       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.74        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00284    |
# |    std                  | 0.838       |
# |    value_loss           | 1.79        |
# -----------------------------------------

# %%
obs = env.reset()
try:
    for _ in range(1000):
        action, _states = model.predict(obs)
        obs, reward, done, info = env.step(action)
        env.render()
        time.sleep(1/50)
        if done:
            env.reset()
finally:
    env.close()
# Out:
# pygame 2.4.0 (SDL 2.26.4, Python 3.10.11)
# Hello from the pygame community. https://www.pygame.org/contribute.html
