# %%
import gym, gym_unbalanced_disk, time
from stable_baselines3 import PPO

# %%
reward_fun = lambda self: (self.th)**2 #example reward function, change this!
env = gym.make('unbalanced-disk-v0', dt=0.025, umax=3., reward_fun=reward_fun) 

model = PPO('MlpPolicy', env, verbose=1) #b)
model.learn(total_timesteps=100_000)
# Out:
# test
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 4.38     |
# | time/              |          |
# |    fps             | 190      |
# |    iterations      | 1        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 8.02         |
# | time/                   |              |
# |    fps                  | 166          |
# |    iterations           | 2            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0065695615 |
# ...

# %%
obs = env.reset()
try:
    for _ in range(1000):
        action, _states = model.predict(obs)
        obs, reward, done, info = env.step(action)
        env.render()
        time.sleep(1/50)
        if done:
            env.reset()
finally:
    env.close()
