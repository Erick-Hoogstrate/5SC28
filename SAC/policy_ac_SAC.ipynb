# %%
import gym, gym_unbalanced_disk, time
import numpy as np
from stable_baselines3 import PPO, SAC
import matplotlib.pyplot as plt
from dataclasses import dataclass

# %%
def normalise_angle(theta):
    return ((theta)%(2*np.pi))-np.pi

# %%
target_angle=np.pi
angle_reward = lambda self: ((np.cos(self.th-target_angle)+1.5)**2 - 0.25)
correctVelocity_reward = lambda self: 0.00125*(((np.cos(self.th)+1)/2)*(self.omega)**2)
voltage_penalty = lambda self: -0.01*((self.u)**2)*(np.sin(self.th-np.pi/2)+1)/2
incorrectAngle_penalty = lambda self: -0.01*np.abs(self.th-target_angle)

reward_lambda = lambda self: angle_reward(self) + correctVelocity_reward(self) + voltage_penalty(self) # + incorrectAngle_penalty(self)
def reward_function(self):
    q=normalise_angle(self.th)
    if (abs(q)<=np.pi/5): return -10*((np.sin(self.th))**2)-2*self.omega**2+20
    else: return reward_lambda(self)

# %%
env = gym.make('unbalanced-disk-v0', dt=0.025, umax=3., reward_fun=reward_function) 

# model = PPO('MlpPolicy', env, verbose=1) #b)
model = SAC('MlpPolicy', env, verbose=3, learning_starts=5000) #b)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=800_000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 13.4     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 1060     |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1200     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 16.2     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 1150     |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2400     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 16.1     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 1150     |
# |    time_elapsed    | 3        |
# |    total_timesteps | 3600     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 18.4     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 1137     |
# |    time_elapsed    | 4        |
# |    total_timesteps | 4800     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 18.7     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 109      |
# |    time_elapsed    | 54       |
# |    total_timesteps | 6000     |
# | train/             |          |
# |    actor_loss      | -3.55    |
# |    critic_loss     | 0.011    |
# |    ent_coef        | 0.741    |
# |    ent_coef_loss   | -0.498   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 999      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | -436     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 56       |
# |    time_elapsed    | 128      |
# |    total_timesteps | 7200     |
# | train/             |          |
# |    actor_loss      | -5.23    |
# |    critic_loss     | 186      |
# |    ent_coef        | 0.535    |
# |    ent_coef_loss   | -0.723   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | -367     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 42       |
# |    time_elapsed    | 197      |
# |    total_timesteps | 8400     |
# | train/             |          |
# |    actor_loss      | -2.05    |
# |    critic_loss     | 308      |
# |    ent_coef        | 0.408    |
# |    ent_coef_loss   | -0.762   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | -310     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 35       |
# |    time_elapsed    | 268      |
# |    total_timesteps | 9600     |
# | train/             |          |
# |    actor_loss      | -14      |
# |    critic_loss     | 6.67     |
# |    ent_coef        | 0.304    |
# |    ent_coef_loss   | -0.86    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | -259     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 31       |
# |    time_elapsed    | 340      |
# |    total_timesteps | 10800    |
# | train/             |          |
# |    actor_loss      | -7.55    |
# |    critic_loss     | 1.23e+03 |
# |    ent_coef        | 0.24     |
# |    ent_coef_loss   | -0.736   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5799     |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | -4.39e+03 |
# | time/              |           |
# |    episodes        | 40        |
# |    fps             | 28        |
# |    time_elapsed    | 414       |
# |    total_timesteps | 12000     |
# | train/             |           |
# |    actor_loss      | 100       |
# |    critic_loss     | 1.06e+05  |
# |    ent_coef        | 0.297     |
# |    ent_coef_loss   | 1.04      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 6999      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | -3.99e+03 |
# | time/              |           |
# |    episodes        | 44        |
# |    fps             | 26        |
# |    time_elapsed    | 492       |
# |    total_timesteps | 13200     |
# | train/             |           |
# |    actor_loss      | 135       |
# |    critic_loss     | 3.48e+04  |
# |    ent_coef        | 0.44      |
# |    ent_coef_loss   | 1.12      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 8199      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | -3.65e+03 |
# | time/              |           |
# |    episodes        | 48        |
# |    fps             | 25        |
# |    time_elapsed    | 568       |
# |    total_timesteps | 14400     |
# | train/             |           |
# |    actor_loss      | 11.7      |
# |    critic_loss     | 9.53e+04  |
# |    ent_coef        | 0.628     |
# |    ent_coef_loss   | 0.209     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 9399      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | -3.37e+03 |
# | time/              |           |
# |    episodes        | 52        |
# |    fps             | 24        |
# |    time_elapsed    | 644       |
# |    total_timesteps | 15600     |
# | train/             |           |
# |    actor_loss      | 10.9      |
# |    critic_loss     | 5.64e+03  |
# |    ent_coef        | 0.764     |
# |    ent_coef_loss   | 0.102     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 10599     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | -3.13e+03 |
# | time/              |           |
# |    episodes        | 56        |
# |    fps             | 23        |
# |    time_elapsed    | 717       |
# |    total_timesteps | 16800     |
# | train/             |           |
# |    actor_loss      | -13.3     |
# |    critic_loss     | 9.27e+04  |
# |    ent_coef        | 0.921     |
# |    ent_coef_loss   | 0.0263    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 11799     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | -2.92e+03 |
# | time/              |           |
# |    episodes        | 60        |
# |    fps             | 22        |
# |    time_elapsed    | 789       |
# |    total_timesteps | 18000     |
# | train/             |           |
# |    actor_loss      | 51.6      |
# |    critic_loss     | 3.23e+04  |
# |    ent_coef        | 1.11      |
# |    ent_coef_loss   | -0.00127  |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 12999     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | -2.73e+03 |
# | time/              |           |
# |    episodes        | 64        |
# |    fps             | 22        |
# |    time_elapsed    | 862       |
# |    total_timesteps | 19200     |
# | train/             |           |
# |    actor_loss      | 101       |
# |    critic_loss     | 4.09e+04  |
# |    ent_coef        | 0.981     |
# |    ent_coef_loss   | 0.00428   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 14199     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | -2.57e+03 |
# | time/              |           |
# |    episodes        | 68        |
# |    fps             | 22        |
# |    time_elapsed    | 889       |
# |    total_timesteps | 20400     |
# | train/             |           |
# |    actor_loss      | 43.7      |
# |    critic_loss     | 6.33e+03  |
# |    ent_coef        | 0.858     |
# |    ent_coef_loss   | -0.0304   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 15399     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | -2.43e+03 |
# | time/              |           |
# |    episodes        | 72        |
# |    fps             | 23        |
# |    time_elapsed    | 908       |
# |    total_timesteps | 21600     |
# | train/             |           |
# |    actor_loss      | -199      |
# |    critic_loss     | 89.1      |
# |    ent_coef        | 0.746     |
# |    ent_coef_loss   | -0.0342   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 16599     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | -2.3e+03 |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 24       |
# |    time_elapsed    | 928      |
# |    total_timesteps | 22800    |
# | train/             |          |
# |    actor_loss      | 414      |
# |    critic_loss     | 4.09e+04 |
# |    ent_coef        | 0.696    |
# |    ent_coef_loss   | 0.0994   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17799    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | -2.18e+03 |
# | time/              |           |
# |    episodes        | 80        |
# |    fps             | 25        |
# |    time_elapsed    | 947       |
# |    total_timesteps | 24000     |
# | train/             |           |
# |    actor_loss      | -14.2     |
# |    critic_loss     | 7.79e+03  |
# |    ent_coef        | 0.672     |
# |    ent_coef_loss   | 0.0854    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 18999     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | -2.08e+03 |
# | time/              |           |
# |    episodes        | 84        |
# |    fps             | 26        |
# |    time_elapsed    | 966       |
# |    total_timesteps | 25200     |
# | train/             |           |
# |    actor_loss      | -11       |
# |    critic_loss     | 1.02e+04  |
# |    ent_coef        | 0.599     |
# |    ent_coef_loss   | 0.108     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 20199     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | -1.98e+03 |
# | time/              |           |
# |    episodes        | 88        |
# |    fps             | 26        |
# |    time_elapsed    | 984       |
# |    total_timesteps | 26400     |
# | train/             |           |
# |    actor_loss      | 141       |
# |    critic_loss     | 9.8e+03   |
# |    ent_coef        | 0.583     |
# |    ent_coef_loss   | 0.0629    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 21399     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | -1.89e+03 |
# | time/              |           |
# |    episodes        | 92        |
# |    fps             | 27        |
# |    time_elapsed    | 1002      |
# |    total_timesteps | 27600     |
# | train/             |           |
# |    actor_loss      | 60.3      |
# |    critic_loss     | 8.06e+04  |
# |    ent_coef        | 0.57      |
# |    ent_coef_loss   | 0.0109    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 22599     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | -1.81e+03 |
# | time/              |           |
# |    episodes        | 96        |
# |    fps             | 28        |
# |    time_elapsed    | 1023      |
# |    total_timesteps | 28800     |
# | train/             |           |
# |    actor_loss      | -125      |
# |    critic_loss     | 272       |
# |    ent_coef        | 0.624     |
# |    ent_coef_loss   | -0.14     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 23799     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | -1.74e+03 |
# | time/              |           |
# |    episodes        | 100       |
# |    fps             | 28        |
# |    time_elapsed    | 1045      |
# |    total_timesteps | 30000     |
# | train/             |           |
# |    actor_loss      | 68.5      |
# |    critic_loss     | 1.44e+03  |
# |    ent_coef        | 0.592     |
# |    ent_coef_loss   | 0.00407   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 24999     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | -1.73e+03 |
# | time/              |           |
# |    episodes        | 104       |
# |    fps             | 28        |
# |    time_elapsed    | 1103      |
# |    total_timesteps | 31200     |
# | train/             |           |
# |    actor_loss      | 63.9      |
# |    critic_loss     | 2.53e+03  |
# |    ent_coef        | 0.6       |
# |    ent_coef_loss   | -0.151    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 26199     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | -1.73e+03 |
# | time/              |           |
# |    episodes        | 108       |
# |    fps             | 28        |
# |    time_elapsed    | 1149      |
# |    total_timesteps | 32400     |
# | train/             |           |
# |    actor_loss      | -166      |
# |    critic_loss     | 57.4      |
# |    ent_coef        | 0.498     |
# |    ent_coef_loss   | -0.0899   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 27399     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | -1.73e+03 |
# | time/              |           |
# |    episodes        | 112       |
# |    fps             | 28        |
# |    time_elapsed    | 1168      |
# |    total_timesteps | 33600     |
# | train/             |           |
# |    actor_loss      | -2.97     |
# |    critic_loss     | 3.57e+03  |
# |    ent_coef        | 0.505     |
# |    ent_coef_loss   | 0.0624    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 28599     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | -1.73e+03 |
# | time/              |           |
# |    episodes        | 116       |
# |    fps             | 29        |
# |    time_elapsed    | 1187      |
# |    total_timesteps | 34800     |
# | train/             |           |
# |    actor_loss      | 186       |
# |    critic_loss     | 1.46e+04  |
# |    ent_coef        | 0.458     |
# |    ent_coef_loss   | 0.00801   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 29799     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | -1.73e+03 |
# | time/              |           |
# |    episodes        | 120       |
# |    fps             | 29        |
# |    time_elapsed    | 1204      |
# |    total_timesteps | 36000     |
# | train/             |           |
# |    actor_loss      | 59.2      |
# |    critic_loss     | 1.7e+04   |
# |    ent_coef        | 0.427     |
# |    ent_coef_loss   | -0.0692   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 30999     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | -1.61e+03 |
# | time/              |           |
# |    episodes        | 124       |
# |    fps             | 30        |
# |    time_elapsed    | 1223      |
# |    total_timesteps | 37200     |
# | train/             |           |
# |    actor_loss      | -144      |
# |    critic_loss     | 16.2      |
# |    ent_coef        | 0.365     |
# |    ent_coef_loss   | -0.146    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 32199     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | -1.61e+03 |
# | time/              |           |
# |    episodes        | 128       |
# |    fps             | 30        |
# |    time_elapsed    | 1244      |
# |    total_timesteps | 38400     |
# | train/             |           |
# |    actor_loss      | 234       |
# |    critic_loss     | 1.6e+03   |
# |    ent_coef        | 0.334     |
# |    ent_coef_loss   | 0.0829    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 33399     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | -1.61e+03 |
# | time/              |           |
# |    episodes        | 132       |
# |    fps             | 31        |
# |    time_elapsed    | 1265      |
# |    total_timesteps | 39600     |
# | train/             |           |
# |    actor_loss      | 38.3      |
# |    critic_loss     | 1.2e+04   |
# |    ent_coef        | 0.34      |
# |    ent_coef_loss   | 0.853     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 34599     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | -1.62e+03 |
# | time/              |           |
# |    episodes        | 136       |
# |    fps             | 31        |
# |    time_elapsed    | 1286      |
# |    total_timesteps | 40800     |
# | train/             |           |
# |    actor_loss      | 53.9      |
# |    critic_loss     | 9.01e+03  |
# |    ent_coef        | 0.352     |
# |    ent_coef_loss   | -0.145    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 35799     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 50.5     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 32       |
# |    time_elapsed    | 1306     |
# |    total_timesteps | 42000    |
# | train/             |          |
# |    actor_loss      | 138      |
# |    critic_loss     | 1.21e+04 |
# |    ent_coef        | 0.309    |
# |    ent_coef_loss   | -0.094   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 36999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 53.4     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 32       |
# |    time_elapsed    | 1326     |
# |    total_timesteps | 43200    |
# | train/             |          |
# |    actor_loss      | -125     |
# |    critic_loss     | 18.6     |
# |    ent_coef        | 0.367    |
# |    ent_coef_loss   | 0.204    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 38199    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 54.4     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 33       |
# |    time_elapsed    | 1345     |
# |    total_timesteps | 44400    |
# | train/             |          |
# |    actor_loss      | 160      |
# |    critic_loss     | 1.11e+04 |
# |    ent_coef        | 0.458    |
# |    ent_coef_loss   | 0.0863   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39399    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 55.3     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 33       |
# |    time_elapsed    | 1362     |
# |    total_timesteps | 45600    |
# | train/             |          |
# |    actor_loss      | -120     |
# |    critic_loss     | 500      |
# |    ent_coef        | 0.435    |
# |    ent_coef_loss   | -0.207   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 40599    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 55.3     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 33       |
# |    time_elapsed    | 1379     |
# |    total_timesteps | 46800    |
# | train/             |          |
# |    actor_loss      | 268      |
# |    critic_loss     | 8.07e+03 |
# |    ent_coef        | 0.326    |
# |    ent_coef_loss   | 0.111    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 41799    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 57.3     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 34       |
# |    time_elapsed    | 1396     |
# |    total_timesteps | 48000    |
# | train/             |          |
# |    actor_loss      | 17.2     |
# |    critic_loss     | 3.4e+03  |
# |    ent_coef        | 0.368    |
# |    ent_coef_loss   | 0.109    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 42999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 60.4     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 34       |
# |    time_elapsed    | 1413     |
# |    total_timesteps | 49200    |
# | train/             |          |
# |    actor_loss      | -83.9    |
# |    critic_loss     | 315      |
# |    ent_coef        | 0.332    |
# |    ent_coef_loss   | 0.108    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 44199    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 63.5     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 35       |
# |    time_elapsed    | 1431     |
# |    total_timesteps | 50400    |
# | train/             |          |
# |    actor_loss      | -88.9    |
# |    critic_loss     | 3.34e+03 |
# |    ent_coef        | 0.266    |
# |    ent_coef_loss   | -0.449   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 45399    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 66.3     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 35       |
# |    time_elapsed    | 1449     |
# |    total_timesteps | 51600    |
# | train/             |          |
# |    actor_loss      | 173      |
# |    critic_loss     | 9.98e+04 |
# |    ent_coef        | 0.269    |
# |    ent_coef_loss   | 0.532    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 46599    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 68.8     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 35       |
# |    time_elapsed    | 1466     |
# |    total_timesteps | 52800    |
# | train/             |          |
# |    actor_loss      | -97.3    |
# |    critic_loss     | 22.5     |
# |    ent_coef        | 0.302    |
# |    ent_coef_loss   | 0.191    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 47799    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 69       |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 36       |
# |    time_elapsed    | 1487     |
# |    total_timesteps | 54000    |
# | train/             |          |
# |    actor_loss      | 322      |
# |    critic_loss     | 6.13e+04 |
# |    ent_coef        | 0.283    |
# |    ent_coef_loss   | 0.36     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 48999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 72.8     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 36       |
# |    time_elapsed    | 1504     |
# |    total_timesteps | 55200    |
# | train/             |          |
# |    actor_loss      | 213      |
# |    critic_loss     | 36.1     |
# |    ent_coef        | 0.311    |
# |    ent_coef_loss   | 0.35     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 50199    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 76.6     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 37       |
# |    time_elapsed    | 1522     |
# |    total_timesteps | 56400    |
# | train/             |          |
# |    actor_loss      | 77       |
# |    critic_loss     | 4.47e+04 |
# |    ent_coef        | 0.323    |
# |    ent_coef_loss   | -0.0575  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 51399    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 82.7     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 37       |
# |    time_elapsed    | 1539     |
# |    total_timesteps | 57600    |
# | train/             |          |
# |    actor_loss      | -85.9    |
# |    critic_loss     | 116      |
# |    ent_coef        | 0.341    |
# |    ent_coef_loss   | -0.401   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 52599    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 88.6     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 37       |
# |    time_elapsed    | 1557     |
# |    total_timesteps | 58800    |
# | train/             |          |
# |    actor_loss      | 113      |
# |    critic_loss     | 4.45e+03 |
# |    ent_coef        | 0.305    |
# |    ent_coef_loss   | -0.116   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 53799    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 93.5     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 38       |
# |    time_elapsed    | 1576     |
# |    total_timesteps | 60000    |
# | train/             |          |
# |    actor_loss      | 27.6     |
# |    critic_loss     | 820      |
# |    ent_coef        | 0.275    |
# |    ent_coef_loss   | -0.222   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 54999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 96.7     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 38       |
# |    time_elapsed    | 1595     |
# |    total_timesteps | 61200    |
# | train/             |          |
# |    actor_loss      | -78.6    |
# |    critic_loss     | 8.54     |
# |    ent_coef        | 0.314    |
# |    ent_coef_loss   | 0.171    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 56199    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 101      |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 38       |
# |    time_elapsed    | 1613     |
# |    total_timesteps | 62400    |
# | train/             |          |
# |    actor_loss      | -35.4    |
# |    critic_loss     | 444      |
# |    ent_coef        | 0.341    |
# |    ent_coef_loss   | 0.277    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 57399    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 104      |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 38       |
# |    time_elapsed    | 1632     |
# |    total_timesteps | 63600    |
# | train/             |          |
# |    actor_loss      | 192      |
# |    critic_loss     | 6.23e+03 |
# |    ent_coef        | 0.312    |
# |    ent_coef_loss   | -0.105   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 58599    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 39       |
# |    time_elapsed    | 1649     |
# |    total_timesteps | 64800    |
# | train/             |          |
# |    actor_loss      | -40.8    |
# |    critic_loss     | 778      |
# |    ent_coef        | 0.288    |
# |    ent_coef_loss   | -0.231   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 59799    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 108      |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 39       |
# |    time_elapsed    | 1666     |
# |    total_timesteps | 66000    |
# | train/             |          |
# |    actor_loss      | -49.5    |
# |    critic_loss     | 13.2     |
# |    ent_coef        | 0.295    |
# |    ent_coef_loss   | 0.41     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 60999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 110      |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 39       |
# |    time_elapsed    | 1683     |
# |    total_timesteps | 67200    |
# | train/             |          |
# |    actor_loss      | 64.6     |
# |    critic_loss     | 2.69e+03 |
# |    ent_coef        | 0.303    |
# |    ent_coef_loss   | 0.328    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 62199    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 114      |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 40       |
# |    time_elapsed    | 1701     |
# |    total_timesteps | 68400    |
# | train/             |          |
# |    actor_loss      | 240      |
# |    critic_loss     | 4.06e+03 |
# |    ent_coef        | 0.323    |
# |    ent_coef_loss   | 0.37     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 63399    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 118      |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 40       |
# |    time_elapsed    | 1718     |
# |    total_timesteps | 69600    |
# | train/             |          |
# |    actor_loss      | -65.7    |
# |    critic_loss     | 20.4     |
# |    ent_coef        | 0.321    |
# |    ent_coef_loss   | -0.201   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 64599    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 122      |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 40       |
# |    time_elapsed    | 1735     |
# |    total_timesteps | 70800    |
# | train/             |          |
# |    actor_loss      | 112      |
# |    critic_loss     | 8.79e+04 |
# |    ent_coef        | 0.358    |
# |    ent_coef_loss   | -0.0212  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 65799    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 129      |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 41       |
# |    time_elapsed    | 1753     |
# |    total_timesteps | 72000    |
# | train/             |          |
# |    actor_loss      | -27.5    |
# |    critic_loss     | 519      |
# |    ent_coef        | 0.387    |
# |    ent_coef_loss   | 0.281    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 66999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 133      |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 41       |
# |    time_elapsed    | 1770     |
# |    total_timesteps | 73200    |
# | train/             |          |
# |    actor_loss      | -65.9    |
# |    critic_loss     | 27.1     |
# |    ent_coef        | 0.401    |
# |    ent_coef_loss   | 0.0947   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 68199    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 141      |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 41       |
# |    time_elapsed    | 1787     |
# |    total_timesteps | 74400    |
# | train/             |          |
# |    actor_loss      | 119      |
# |    critic_loss     | 6.22e+03 |
# |    ent_coef        | 0.436    |
# |    ent_coef_loss   | 0.172    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 69399    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 152      |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 41       |
# |    time_elapsed    | 1804     |
# |    total_timesteps | 75600    |
# | train/             |          |
# |    actor_loss      | -66      |
# |    critic_loss     | 8.62     |
# |    ent_coef        | 0.43     |
# |    ent_coef_loss   | -0.174   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 70599    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 161      |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 42       |
# |    time_elapsed    | 1820     |
# |    total_timesteps | 76800    |
# | train/             |          |
# |    actor_loss      | -49.7    |
# |    critic_loss     | 63.4     |
# |    ent_coef        | 0.426    |
# |    ent_coef_loss   | -0.0473  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 71799    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 167      |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 42       |
# |    time_elapsed    | 1837     |
# |    total_timesteps | 78000    |
# | train/             |          |
# |    actor_loss      | -65.6    |
# |    critic_loss     | 19.1     |
# |    ent_coef        | 0.438    |
# |    ent_coef_loss   | 0.0549   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 72999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 172      |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 42       |
# |    time_elapsed    | 1854     |
# |    total_timesteps | 79200    |
# | train/             |          |
# |    actor_loss      | -59.1    |
# |    critic_loss     | 2.54e+03 |
# |    ent_coef        | 0.438    |
# |    ent_coef_loss   | 0.0311   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 74199    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 181      |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 42       |
# |    time_elapsed    | 1871     |
# |    total_timesteps | 80400    |
# | train/             |          |
# |    actor_loss      | -32.2    |
# |    critic_loss     | 278      |
# |    ent_coef        | 0.427    |
# |    ent_coef_loss   | -0.0989  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 75399    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 192      |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 43       |
# |    time_elapsed    | 1889     |
# |    total_timesteps | 81600    |
# | train/             |          |
# |    actor_loss      | -66.4    |
# |    critic_loss     | 12       |
# |    ent_coef        | 0.407    |
# |    ent_coef_loss   | 0.0696   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 76599    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 205      |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 43       |
# |    time_elapsed    | 1906     |
# |    total_timesteps | 82800    |
# | train/             |          |
# |    actor_loss      | 143      |
# |    critic_loss     | 1.19e+04 |
# |    ent_coef        | 0.427    |
# |    ent_coef_loss   | 0.0836   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 77799    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 215      |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 43       |
# |    time_elapsed    | 1923     |
# |    total_timesteps | 84000    |
# | train/             |          |
# |    actor_loss      | -65.1    |
# |    critic_loss     | 6.66     |
# |    ent_coef        | 0.381    |
# |    ent_coef_loss   | 0.145    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 78999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 221      |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 43       |
# |    time_elapsed    | 1940     |
# |    total_timesteps | 85200    |
# | train/             |          |
# |    actor_loss      | -66      |
# |    critic_loss     | 13.1     |
# |    ent_coef        | 0.382    |
# |    ent_coef_loss   | -0.143   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 80199    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 230      |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 44       |
# |    time_elapsed    | 1957     |
# |    total_timesteps | 86400    |
# | train/             |          |
# |    actor_loss      | -61.7    |
# |    critic_loss     | 10.7     |
# |    ent_coef        | 0.414    |
# |    ent_coef_loss   | -0.123   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 81399    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 235      |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 44       |
# |    time_elapsed    | 1974     |
# |    total_timesteps | 87600    |
# | train/             |          |
# |    actor_loss      | -60.2    |
# |    critic_loss     | 38.2     |
# |    ent_coef        | 0.351    |
# |    ent_coef_loss   | 0.0548   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 82599    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 241      |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 44       |
# |    time_elapsed    | 1991     |
# |    total_timesteps | 88800    |
# | train/             |          |
# |    actor_loss      | -61      |
# |    critic_loss     | 8.89     |
# |    ent_coef        | 0.306    |
# |    ent_coef_loss   | -0.032   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 83799    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 248      |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 44       |
# |    time_elapsed    | 2008     |
# |    total_timesteps | 90000    |
# | train/             |          |
# |    actor_loss      | -60.9    |
# |    critic_loss     | 53.1     |
# |    ent_coef        | 0.311    |
# |    ent_coef_loss   | -0.0159  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 84999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 262      |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 45       |
# |    time_elapsed    | 2026     |
# |    total_timesteps | 91200    |
# | train/             |          |
# |    actor_loss      | -48.6    |
# |    critic_loss     | 664      |
# |    ent_coef        | 0.34     |
# |    ent_coef_loss   | 0.11     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 86199    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 267      |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 45       |
# |    time_elapsed    | 2046     |
# |    total_timesteps | 92400    |
# | train/             |          |
# |    actor_loss      | -58.1    |
# |    critic_loss     | 18.9     |
# |    ent_coef        | 0.301    |
# |    ent_coef_loss   | -0.0997  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 87399    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 271      |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 45       |
# |    time_elapsed    | 2066     |
# |    total_timesteps | 93600    |
# | train/             |          |
# |    actor_loss      | -57.8    |
# |    critic_loss     | 64.2     |
# |    ent_coef        | 0.304    |
# |    ent_coef_loss   | 0.0552   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 88599    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 279      |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 45       |
# |    time_elapsed    | 2085     |
# |    total_timesteps | 94800    |
# | train/             |          |
# |    actor_loss      | -22      |
# |    critic_loss     | 1.41e+03 |
# |    ent_coef        | 0.283    |
# |    ent_coef_loss   | -0.298   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 89799    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 289      |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 45       |
# |    time_elapsed    | 2105     |
# |    total_timesteps | 96000    |
# | train/             |          |
# |    actor_loss      | -56.3    |
# |    critic_loss     | 3.44     |
# |    ent_coef        | 0.277    |
# |    ent_coef_loss   | 0.0423   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 90999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 304      |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 45       |
# |    time_elapsed    | 2125     |
# |    total_timesteps | 97200    |
# | train/             |          |
# |    actor_loss      | -30.2    |
# |    critic_loss     | 779      |
# |    ent_coef        | 0.297    |
# |    ent_coef_loss   | 0.182    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 92199    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 308      |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 45       |
# |    time_elapsed    | 2145     |
# |    total_timesteps | 98400    |
# | train/             |          |
# |    actor_loss      | -55.5    |
# |    critic_loss     | 8.01     |
# |    ent_coef        | 0.296    |
# |    ent_coef_loss   | -0.0385  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 93399    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 319      |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 46       |
# |    time_elapsed    | 2165     |
# |    total_timesteps | 99600    |
# | train/             |          |
# |    actor_loss      | -56.6    |
# |    critic_loss     | 6.74     |
# |    ent_coef        | 0.287    |
# |    ent_coef_loss   | -0.0821  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 94599    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 328      |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 46       |
# |    time_elapsed    | 2184     |
# |    total_timesteps | 100800   |
# | train/             |          |
# |    actor_loss      | -55.6    |
# |    critic_loss     | 10.6     |
# |    ent_coef        | 0.279    |
# |    ent_coef_loss   | 0.348    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 95799    |
# ...
# |    n_updates       | 761799   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | 5.41e+03  |
# | time/              |           |
# |    episodes        | 2560      |
# |    fps             | 64        |
# |    time_elapsed    | 11948     |
# |    total_timesteps | 768000    |
# | train/             |           |
# |    actor_loss      | -1.73e+03 |
# |    critic_loss     | 48.6      |
# |    ent_coef        | 1.1       |
# |    ent_coef_loss   | -0.000634 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 762999    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | 5.42e+03  |
# | time/              |           |
# |    episodes        | 2564      |
# |    fps             | 64        |
# |    time_elapsed    | 11965     |
# |    total_timesteps | 769200    |
# | train/             |           |
# |    actor_loss      | -1.67e+03 |
# |    critic_loss     | 75.9      |
# |    ent_coef        | 1.05      |
# |    ent_coef_loss   | -0.00244  |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 764199    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | 5.42e+03  |
# | time/              |           |
# |    episodes        | 2568      |
# |    fps             | 64        |
# |    time_elapsed    | 11983     |
# |    total_timesteps | 770400    |
# | train/             |           |
# |    actor_loss      | -1.68e+03 |
# |    critic_loss     | 247       |
# |    ent_coef        | 1.09      |
# |    ent_coef_loss   | -0.0214   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 765399    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | 5.42e+03  |
# | time/              |           |
# |    episodes        | 2572      |
# |    fps             | 64        |
# |    time_elapsed    | 12000     |
# |    total_timesteps | 771600    |
# | train/             |           |
# |    actor_loss      | -1.69e+03 |
# |    critic_loss     | 161       |
# |    ent_coef        | 1.08      |
# |    ent_coef_loss   | -0.013    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 766599    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | 5.41e+03  |
# | time/              |           |
# |    episodes        | 2576      |
# |    fps             | 64        |
# |    time_elapsed    | 12018     |
# |    total_timesteps | 772800    |
# | train/             |           |
# |    actor_loss      | -1.68e+03 |
# |    critic_loss     | 366       |
# |    ent_coef        | 1.08      |
# |    ent_coef_loss   | -0.0155   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 767799    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 5.41e+03 |
# | time/              |          |
# |    episodes        | 2580     |
# |    fps             | 64       |
# |    time_elapsed    | 12035    |
# |    total_timesteps | 774000   |
# | train/             |          |
# |    actor_loss      | -1.7e+03 |
# |    critic_loss     | 34.3     |
# |    ent_coef        | 1.03     |
# |    ent_coef_loss   | -0.00217 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 768999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 5.41e+03 |
# | time/              |          |
# |    episodes        | 2584     |
# |    fps             | 64       |
# |    time_elapsed    | 12053    |
# |    total_timesteps | 775200   |
# | train/             |          |
# |    actor_loss      | -1.7e+03 |
# |    critic_loss     | 55       |
# |    ent_coef        | 1.04     |
# |    ent_coef_loss   | -0.00318 |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 770199   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 5.41e+03 |
# | time/              |          |
# |    episodes        | 2588     |
# |    fps             | 64       |
# |    time_elapsed    | 12070    |
# |    total_timesteps | 776400   |
# | train/             |          |
# |    actor_loss      | -1.7e+03 |
# |    critic_loss     | 584      |
# |    ent_coef        | 1.02     |
# |    ent_coef_loss   | 0.00274  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 771399   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | 5.41e+03  |
# | time/              |           |
# |    episodes        | 2592      |
# |    fps             | 64        |
# |    time_elapsed    | 12088     |
# |    total_timesteps | 777600    |
# | train/             |           |
# |    actor_loss      | -1.56e+03 |
# |    critic_loss     | 6.21e+04  |
# |    ent_coef        | 1.01      |
# |    ent_coef_loss   | -0.000449 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 772599    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | 5.41e+03  |
# | time/              |           |
# |    episodes        | 2596      |
# |    fps             | 64        |
# |    time_elapsed    | 12105     |
# |    total_timesteps | 778800    |
# | train/             |           |
# |    actor_loss      | -1.72e+03 |
# |    critic_loss     | 40.7      |
# |    ent_coef        | 1.1       |
# |    ent_coef_loss   | 0.00315   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 773799    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | 5.41e+03  |
# | time/              |           |
# |    episodes        | 2600      |
# |    fps             | 64        |
# |    time_elapsed    | 12122     |
# |    total_timesteps | 780000    |
# | train/             |           |
# |    actor_loss      | -1.72e+03 |
# |    critic_loss     | 38.5      |
# |    ent_coef        | 1.07      |
# |    ent_coef_loss   | 0.00784   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 774999    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | 5.41e+03  |
# | time/              |           |
# |    episodes        | 2604      |
# |    fps             | 64        |
# |    time_elapsed    | 12140     |
# |    total_timesteps | 781200    |
# | train/             |           |
# |    actor_loss      | -1.54e+03 |
# |    critic_loss     | 1.2e+04   |
# |    ent_coef        | 1.08      |
# |    ent_coef_loss   | 0.00173   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 776199    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | 5.41e+03  |
# | time/              |           |
# |    episodes        | 2608      |
# |    fps             | 64        |
# |    time_elapsed    | 12157     |
# |    total_timesteps | 782400    |
# | train/             |           |
# |    actor_loss      | -1.72e+03 |
# |    critic_loss     | 87.1      |
# |    ent_coef        | 1.07      |
# |    ent_coef_loss   | -0.0133   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 777399    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 5.41e+03 |
# | time/              |          |
# |    episodes        | 2612     |
# |    fps             | 64       |
# |    time_elapsed    | 12175    |
# |    total_timesteps | 783600   |
# | train/             |          |
# |    actor_loss      | -1.7e+03 |
# |    critic_loss     | 40.1     |
# |    ent_coef        | 1.05     |
# |    ent_coef_loss   | 0.00814  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 778599   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | 5.41e+03  |
# | time/              |           |
# |    episodes        | 2616      |
# |    fps             | 64        |
# |    time_elapsed    | 12192     |
# |    total_timesteps | 784800    |
# | train/             |           |
# |    actor_loss      | -1.72e+03 |
# |    critic_loss     | 105       |
# |    ent_coef        | 1.04      |
# |    ent_coef_loss   | 0.00487   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 779799    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | 5.41e+03  |
# | time/              |           |
# |    episodes        | 2620      |
# |    fps             | 64        |
# |    time_elapsed    | 12209     |
# |    total_timesteps | 786000    |
# | train/             |           |
# |    actor_loss      | -1.74e+03 |
# |    critic_loss     | 27.5      |
# |    ent_coef        | 1.04      |
# |    ent_coef_loss   | 0.00635   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 780999    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | 5.41e+03  |
# | time/              |           |
# |    episodes        | 2624      |
# |    fps             | 64        |
# |    time_elapsed    | 12227     |
# |    total_timesteps | 787200    |
# | train/             |           |
# |    actor_loss      | -1.72e+03 |
# |    critic_loss     | 48.1      |
# |    ent_coef        | 1.08      |
# |    ent_coef_loss   | 0.0171    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 782199    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 5.41e+03 |
# | time/              |          |
# |    episodes        | 2628     |
# |    fps             | 64       |
# |    time_elapsed    | 12244    |
# |    total_timesteps | 788400   |
# | train/             |          |
# |    actor_loss      | -1.7e+03 |
# |    critic_loss     | 144      |
# |    ent_coef        | 1.05     |
# |    ent_coef_loss   | 0.00183  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 783399   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | 5.41e+03  |
# | time/              |           |
# |    episodes        | 2632      |
# |    fps             | 64        |
# |    time_elapsed    | 12262     |
# |    total_timesteps | 789600    |
# | train/             |           |
# |    actor_loss      | -1.69e+03 |
# |    critic_loss     | 33.5      |
# |    ent_coef        | 1         |
# |    ent_coef_loss   | 0.000104  |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 784599    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | 5.41e+03  |
# | time/              |           |
# |    episodes        | 2636      |
# |    fps             | 64        |
# |    time_elapsed    | 12279     |
# |    total_timesteps | 790800    |
# | train/             |           |
# |    actor_loss      | -1.71e+03 |
# |    critic_loss     | 48.9      |
# |    ent_coef        | 1.08      |
# |    ent_coef_loss   | -0.0192   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 785799    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | 5.4e+03   |
# | time/              |           |
# |    episodes        | 2640      |
# |    fps             | 64        |
# |    time_elapsed    | 12297     |
# |    total_timesteps | 792000    |
# | train/             |           |
# |    actor_loss      | -1.69e+03 |
# |    critic_loss     | 44.2      |
# |    ent_coef        | 1.01      |
# |    ent_coef_loss   | -0.000666 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 786999    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 5.4e+03  |
# | time/              |          |
# |    episodes        | 2644     |
# |    fps             | 64       |
# |    time_elapsed    | 12314    |
# |    total_timesteps | 793200   |
# | train/             |          |
# |    actor_loss      | -1.7e+03 |
# |    critic_loss     | 449      |
# |    ent_coef        | 0.978    |
# |    ent_coef_loss   | 0.00163  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 788199   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 5.4e+03  |
# | time/              |          |
# |    episodes        | 2648     |
# |    fps             | 64       |
# |    time_elapsed    | 12331    |
# |    total_timesteps | 794400   |
# | train/             |          |
# |    actor_loss      | -1.7e+03 |
# |    critic_loss     | 49.8     |
# |    ent_coef        | 1.06     |
# |    ent_coef_loss   | -0.0119  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 789399   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | 5.4e+03   |
# | time/              |           |
# |    episodes        | 2652      |
# |    fps             | 64        |
# |    time_elapsed    | 12349     |
# |    total_timesteps | 795600    |
# | train/             |           |
# |    actor_loss      | -1.71e+03 |
# |    critic_loss     | 43.2      |
# |    ent_coef        | 1         |
# |    ent_coef_loss   | -3.37e-05 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 790599    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 5.4e+03  |
# | time/              |          |
# |    episodes        | 2656     |
# |    fps             | 64       |
# |    time_elapsed    | 12366    |
# |    total_timesteps | 796800   |
# | train/             |          |
# |    actor_loss      | -1.6e+03 |
# |    critic_loss     | 2.92e+03 |
# |    ent_coef        | 0.989    |
# |    ent_coef_loss   | 0.00141  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 791799   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | 5.4e+03   |
# | time/              |           |
# |    episodes        | 2660      |
# |    fps             | 64        |
# |    time_elapsed    | 12384     |
# |    total_timesteps | 798000    |
# | train/             |           |
# |    actor_loss      | -1.72e+03 |
# |    critic_loss     | 35.6      |
# |    ent_coef        | 1         |
# |    ent_coef_loss   | -0.000172 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 792999    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 300       |
# |    ep_rew_mean     | 5.39e+03  |
# | time/              |           |
# |    episodes        | 2664      |
# |    fps             | 64        |
# |    time_elapsed    | 12401     |
# |    total_timesteps | 799200    |
# | train/             |           |
# |    actor_loss      | -1.68e+03 |
# |    critic_loss     | 48.2      |
# |    ent_coef        | 0.954     |
# |    ent_coef_loss   | 0.00222   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 794199    |
# ----------------------------------

# %%
model.save('SAC_working_save5')

# %%
# model=SAC.load('SAC_working_save4.zip')

# %%
env.close()
env = gym.make('unbalanced-disk-v0', dt=0.025, umax=3.,reward_fun=reward_function,noise_scale=1e-3) 
render_sim = True
obs = env.reset()
u_list=[]
thetas=[]
omegas=[]
rewards=[]
try:
    for _ in range(1000):
        action, _states = model.predict(obs)
        obs, reward, done, info = env.step(action)
        if render_sim:
            env.render()
        u_list.append(action)
        thetas.append(obs[0])
        omegas.append(obs[1])
        rewards.append(reward)
        if render_sim:
            time.sleep(1/50)
        if done:
            obs=env.reset()
finally:
    env.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[205], line 20
#      18 rewards.append(reward)
#      19 if render_sim:
# ---> 20     time.sleep(1/50)
#      21 if done:
#      22     obs=env.reset()
#
# KeyboardInterrupt:

# %%
def get_color(q):
    if abs(q) > 2 * np.pi / 3:  # lower 120
        c=0
    elif abs(q) > np.pi / 3:  # either side
        c=1
    else:  # top
        c=2
    if abs(q)<=np.pi/4:
        c=3
    return c

def compute_reward_sim(self):
    q = normalise_angle(self.th)
    r=reward_function(self)
    c=get_color(q)
    return q, r, c

# %%
@dataclass
class Data:
    th = None
    omega = None
    u = None

# %%
if False:
    import json
    with open('SAC_irl_results.json') as f:
        results=json.load(f)
    u_list=results['u_list']
    omegas=results['omegas']
    thetas=results['thetas']
    rewards=results['rewards']

# %%
target_angle=np.pi
angle_reward = lambda self: ((np.cos(self.th-target_angle)+1.5)**2 - 0.25)
correctVelocity_reward = lambda self: 0.00125*(((np.cos(self.th)+1)/2)*(self.omega)**2)
voltage_penalty = lambda self: -0.01*((self.u)**2)*(np.sin(self.th-np.pi/2)+1)/2
incorrectAngle_penalty = lambda self: -0.01*np.abs(self.th-target_angle)

reward_lambda = lambda self: angle_reward(self) + correctVelocity_reward(self) + voltage_penalty(self) # + incorrectAngle_penalty(self)
def reward_function(self):
    q=normalise_angle(self.th)
    if (abs(q)<=np.pi/5): return -10*((np.sin(self.th))**2)-2*self.omega**2+20
    else: return reward_lambda(self)

# %%
rewards_sim=[]
colors=[]
thetas_norm=[]
colormap = np.array(['r', 'g', 'b'])
for i in range(len(u_list)):
    data=Data()
    data.th=thetas[i]
    data.omega=omegas[i]
    data.u=u_list[i]
    q, r,c = compute_reward_sim(data, )
    rewards_sim.append(r)
    colors.append(c)
    thetas_norm.append(q)

rewards_sim=np.array(rewards_sim)
rewards_sim=rewards_sim
colormap = np.array(['r', 'g', 'b', 'black'])


plot_start=0#np.argmax(rewards)
plot_end=plot_start+80

plt.figure(figsize=(12,12))
[plt.axhline(x, ls='--',c='black',alpha=0.4) for x in np.arange(-1,1.1,1/4)*np.pi]
target_data=Data()
target_data.th, target_data.u, target_data.omega = np.pi, 0, 0
plt.plot(thetas[plot_start:plot_end], label='theta')
# plt.plot(np.cos(thetas[plot_start:plot_end]), label='cos_theta')
plt.plot(np.sin(thetas[plot_start:plot_end-15]+[-np.pi]*15), label='sin_theta')
plt.plot(thetas_norm[plot_start:plot_end], label='theta norm')
plt.plot(omegas[plot_start:plot_end], label='omega')
# plt.plot(np.array(omegas[:plot_end])**2, label='omega^2')
plt.plot(u_list[plot_start:plot_end], label='u list')
plt.plot(rewards[plot_start:plot_end], linewidth=2, label='reward')
plt.hlines([reward_function(target_data)],plot_start,plot_end)
plt.scatter([*range(len(u_list[plot_start:plot_end]))], rewards_sim[plot_start:plot_end], ls='--', linewidth=2, label='reward sim', c=colormap[colors[plot_start:plot_end]])
plt.legend()
# plt.ylim(-10, 7.5)
plt.xlim(plot_start,plot_end)
plt.show()
