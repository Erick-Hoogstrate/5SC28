# %%
import pickle

# %%
# reg = pickle.load(open(File_name_load,"rb"))

# %%
import sys
import numpy as np
from scipy.io import loadmat

from matplotlib import pyplot as plt

# %%
# data = np.load('test-prediction-example-submission-file.npz') #filled
data = np.load('test-prediction-submission-file.npz') #empty

upast = data['upast']
thpast = data['thpast']
thnow = data['thnow']

# %%
print(len(upast))
print(len(thpast))
print(len(thnow))
# Out:
# 1366
# 1366
# 1366

# %%
plt.scatter(upast, thpast)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Plot from .npz file')
plt.show()

# %%
print(len(upast))
print(len(thpast))
print(len(thnow))
# Out:
# 1366
# 1366
# 1366

# %%
plt.plot(upast)

# %%
plt.plot(thnow)
