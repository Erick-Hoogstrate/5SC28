# %%
import gym
import numpy as np

from stable_baselines3 import DDPG
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise

env = gym.make("Pendulum-v1")

# The noise objects for DDPG
n_actions = env.action_space.shape[-1]
action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))

model = DDPG("MlpPolicy", env, action_noise=action_noise, verbose=1)
model.learn(total_timesteps=10000, log_interval=10)
model.save("ddpg_pendulum")
vec_env = model.get_env()

del model # remove to demonstrate saving and loading

model = DDPG.load("ddpg_pendulum")

obs = vec_env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = vec_env.step(action)
    env.render("human")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.56e+03 |
# | time/              |           |
# |    episodes        | 10        |
# |    fps             | 89        |
# |    time_elapsed    | 22        |
# |    total_timesteps | 2000      |
# | train/             |           |
# |    actor_loss      | 64.5      |
# |    critic_loss     | 0.108     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1800      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.39e+03 |
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 79        |
# |    time_elapsed    | 50        |
# |    total_timesteps | 4000      |
# | train/             |           |
# |    actor_loss      | 114       |
# |    critic_loss     | 0.372     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 3800      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.24e+03 |
# | time/              |           |
# |    episodes        | 30        |
# |    fps             | 74        |
# |    time_elapsed    | 80        |
# |    total_timesteps | 6000      |
# | train/             |           |
# |    actor_loss      | 141       |
# |    critic_loss     | 0.961     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 5800      |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -1e+03   |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 72       |
# |    time_elapsed    | 109      |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | 151      |
# |    critic_loss     | 0.845    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7800     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -832     |
# | time/              |          |
# |    episodes        | 50       |
# |    fps             | 71       |
# |    time_elapsed    | 140      |
# |    total_timesteps | 10000    |
# | train/             |          |
# |    actor_loss      | 146      |
# |    critic_loss     | 1.32     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9800     |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 26
#      24 action, _states = model.predict(obs)
#      25 obs, rewards, dones, info = vec_env.step(action)
# ---> 26 env.render("human")
#
# File ~\AppData\Local\anaconda3\envs\ml4sc\lib\site-packages\gym\core.py:295, in Wrapper.render(self, mode, **kwargs)
#     294 def render(self, mode="human", **kwargs):
# --> 295     return self.env.render(mode, **kwargs)
#
# File ~\AppData\Local\anaconda3\envs\ml4sc\lib\site-packages\gym\envs\classic_control\pendulum.py:85, in PendulumEnv.render(self, mode)
#      82 if self.last_u is not None:
#      83     self.imgtrans.scale = (-self.last_u / 2, np.abs(self.last_u) / 2)
# ---> 85 return self.viewer.render(return_rgb_array=mode == "rgb_array")
#
# File ~\AppData\Local\anaconda3\envs\ml4sc\lib\site-packages\gym\envs\classic_control\rendering.py:145, in Viewer.render(self, return_rgb_array)
#     143     arr = arr.reshape(buffer.height, buffer.width, 4)
#     144     arr = arr[::-1, :, 0:3]
# --> 145 self.window.flip()
#     146 self.onetime_geoms = []
#     147 return arr if return_rgb_array else self.isopen
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pyglet\window\win32\__init__.py:379, in Win32Window.flip(self)
#     377     if self._always_dwm or self._dwm_composition_enabled():
#     378         if self._interval:
# --> 379             _dwmapi.DwmFlush()
#     381 if self.style in ('overlay', 'transparent'):
#     382     self.update_transparency()
#
# KeyboardInterrupt:
