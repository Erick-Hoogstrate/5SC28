# %%
import sys
sys.path.append('gym-unbalanced-disk/gym_unbalanced_disk/')
from torch import nn
import torch, gym, gym_unbalanced_disk, time, gym.wrappers
import numpy as np
from matplotlib import pyplot as plt
from copy import deepcopy
import os
import datetime

# %% [markdown]
# # QFUNCTION NOG AANPASSEN

# %%
class Qfunction(nn.Module):
    def __init__(self, env):
        super(Qfunction,self).__init__()
        self.lay1 = nn.Linear(env.observation_space.shape[0], 40)
        self.F1 =  nn.Tanh() #a)
        self.lay2 = nn.Linear(40,env.action_space.n)
    
    def forward(self, obs):
        return self.lay2(self.F1(self.lay1(obs)))

# %%
def show(Q,env):
    u = []
    theta = []
    omega = []
    with torch.no_grad():
        #you can use Qfun(obs) as a shorthand for the q function.
        Qfun = lambda x: Q(torch.tensor(x[None,:],dtype=torch.float32))[0].numpy() #convert x to torch.tensor -> put in the Q function -> back to numpy
        try:
            obs = env.reset() #b)
            env.render() #b)
            time.sleep(10) # give time to open window
            while True: #b)
                action = np.argmax(Qfun(obs)) #b)
                obs, reward, done, info = env.step(action) #b)
                time.sleep(1/60) #b)
                env.render() #b)
                u.append(env.u)
                theta.append(env.th)
                omega.append(env.omega)
                if done: #b)
                    time.sleep(0.5)  #b)
                    break  #b)
        finally: #this will always run even when an error occurs
            env.close()
            return u,theta,omega

# %%
def rollout(Q, env, epsilon=0.1, N_rollout=10_000): 
    #save the following (use .append)
    Start_state = [] #hold an array of (x_t)
    Actions = [] #hold an array of (u_t)
    Rewards = [] #hold an array of (r_{t+1})
    End_state = [] #hold an array of (x_{t+1})
    Terminal = [] #hold an array of (terminal_{t+1})
    # Qfun( a numpy array of the obs) -> a numpy array of Q values
    Qfun = lambda x: Q(torch.tensor(x[None,:],dtype=torch.float32))[0].numpy() 
    with torch.no_grad():
        
        obs = env.reset() #c)
        for i in range(N_rollout): #c)
            if np.random.uniform()>epsilon: #c)
                Qnow = Qfun(obs) #c)
                action = np.argmax(Qnow) #c)
            else: #c)
                action = env.action_space.sample() #c)
            Start_state.append(obs) #c)
            Actions.append(action) #c)

            obs_next, reward, done, info = env.step(action) #c)
            terminal = done and not info.get('TimeLimit.truncated', False) #c)

            Terminal.append(terminal) #c)
            Rewards.append(reward) #c)
            End_state.append(obs_next) #c)

            if done: #c)
                obs = env.reset() #c)
            else: #c)
                obs = obs_next #c)
                
    #error checking:
    assert len(Start_state)==len(Actions)==len(Rewards)==len(End_state)==len(Terminal), f'error in lengths: {len(Start_state)}=={len(Actions)}=={len(Rewards)}=={len(End_state)}=={len(Dones)}'
    return np.array(Start_state), np.array(Actions), np.array(Rewards), np.array(End_state), np.array(Terminal).astype(int)

# %%
def eval_Q(Q,env):
    with torch.no_grad():
        Qfun = lambda x: Q(torch.tensor(x[None,:],dtype=torch.float32))[0].numpy()
        rewards_acc = 0 #d)
        obs = env.reset() #d)
        while True: #d)
            action = np.argmax(Qfun(obs)) #d)
            obs, reward, done, info = env.step(action) #d)
            rewards_acc += reward #d)
            if done: #d)
                return rewards_acc #d)

# %%
def DQN_rollout(Q, optimizer, env, gamma=0.98, use_target_net=False, N_iterations=21, N_rollout=20000, \
                N_epochs=10, batch_size=32, N_evals=10, target_net_update_feq=100):
    best = -float('inf')
    torch.save(Q.state_dict(),'Q-checkpoint')
    try:
        for iteration in range(N_iterations):
            epsilon = 1.0 - iteration/(N_iterations-1) #e=) 1.
            print(f'rollout iteration {iteration} with epsilon={epsilon:.2%}...')
            
            #2. rollout
            Start_state, Actions, Rewards, End_state, Dones = rollout(Q, env, epsilon=epsilon, N_rollout=N_rollout) #e) 2.
            
            #Data conversion, no changes required
            convert = lambda x: [torch.tensor(xi,dtype=torch.float32) for xi in x]
            Start_state, Rewards, End_state, Dones = convert([Start_state, Rewards, End_state, Dones])
            Actions = Actions.astype(int)

            print('starting training on rollout information...')
            t = 0
            for epoch in range(N_epochs): 
                for i in range(batch_size,len(Start_state)+1,batch_size): 
                    if t%target_net_update_feq==0:
                        Qtarget = deepcopy(Q) #g)
                        pass
                    t += 1
                    
                    Start_state_batch, Actions_batch, Rewards_batch, End_state_batch, Dones_batch = [d[i-batch_size:i] for d in [Start_state, Actions, Rewards, End_state, Dones]] #e=) 3.
                    
                    with torch.no_grad(): #3.
                        if use_target_net:
                            maxQ = torch.max(Qtarget(End_state_batch),dim=1)[0] #g)
                        else:
                            maxQ = torch.max(Q(End_state_batch),dim=1)[0] #e=) 3.
                    
                    action_index = np.stack((np.arange(batch_size),Actions_batch),axis=0)
                    Qnow = Q(Start_state_batch)[action_index] #Q(x_t,u_t) is given
                    
                    Loss = torch.mean((Rewards_batch + gamma*maxQ*(1-Dones_batch) - Qnow)**2) #e) 3.
                    optimizer.zero_grad() #e) 3.
                    Loss.backward() #e) 3.
                    optimizer.step() #e) 3.
                
                score = np.mean([eval_Q(Q,env) for i in range(N_evals)]) #e=) 3.
                
                print(f'iteration={iteration} epoch={epoch} Average Reward per episode:',score)
                if score>best:
                    best = score
                    print('################################# \n new best',best,'saving Q... \n#################################')
                    torch.save(Q.state_dict(),'Q-checkpoint7')
            
            print('loading best result')
            Q.load_state_dict(torch.load('Q-checkpoint7'))
    finally: #this will always run even when using the a KeyBoard Interrupt. 
        print('loading best result')
        Q.load_state_dict(torch.load('Q-checkpoint7'))

# %%
target_angle = np.pi # target set to be balanced on top

# %%
angle_reward = lambda self: ((np.cos(self.th-target_angle)+1.5)**2 - 0.25)
correctVelocity_reward = lambda self: 0.00250*(((np.cos(self.th)+1)/2)*(self.omega)**2)
voltage_penalty = lambda self: -0.005*((self.u)**2)
incorrectAngle_penalty = lambda self: -0.05*np.abs(self.th-target_angle)

reward_function = lambda self: angle_reward(self) + correctVelocity_reward(self) + voltage_penalty(self) + incorrectAngle_penalty(self)

max_episode_steps = 300
gamma = 0.98
batch_size = 32
N_iterations = 15
N_rollout = 10000
N_epochs = 10
N_evals = 5
lr = 0.0005

# %%
env = gym.make('unbalanced-disk-sincos-v0', dt=0.025, umax=3.)
env = gym.wrappers.time_limit.TimeLimit(env,max_episode_steps=max_episode_steps)
env.change_reward_function(reward_function)
# Out:
# Running from folder

# %%
# env.set_discrete_values(discrete_size = 9, minmax = 3.0, div = 2.5, rnd = 2)
# env.set_discrete_values_manual([-3.0, -1.5, -0.75, -0.5, -0.25, -0.15, -0.1, 0, 0.1, 0.15, 0.25, 0.5, 0.75, 1.5, 3.0])
env.set_discrete_values_manual([-3.0, -0.9, 0, 0.9, 3.0])
# Out:
# Discrete value set changed to [-3.0, -0.9, 0, 0.9, 3.0]

# %%
assert isinstance(env.action_space,gym.spaces.Discrete), 'action space requires to be discrete'
Q = Qfunction(env)
optimizer = torch.optim.Adam(Q.parameters(),lr=lr) #low learning rate
DQN_rollout(Q, optimizer, env, use_target_net=True, gamma=gamma, N_iterations=N_iterations, \
            N_rollout=N_rollout, N_epochs=N_epochs, N_evals=N_evals)
# Out:
# rollout iteration 0 with epsilon=100.00%...
# starting training on rollout information...
# iteration=0 epoch=0 Average Reward per episode: 53.692803809665406
# #################################
#  new best 53.692803809665406 saving Q...
# #################################
# iteration=0 epoch=1 Average Reward per episode: 40.32737516833694
# iteration=0 epoch=2 Average Reward per episode: 43.95360620614203
# iteration=0 epoch=3 Average Reward per episode: 32.3888638916846
# iteration=0 epoch=4 Average Reward per episode: 82.27612905642539
# #################################
#  new best 82.27612905642539 saving Q...
# #################################
# iteration=0 epoch=5 Average Reward per episode: 78.01554964387311
# iteration=0 epoch=6 Average Reward per episode: 188.31753634744186
# #################################
#  new best 188.31753634744186 saving Q...
# #################################
# iteration=0 epoch=7 Average Reward per episode: 259.5898495230441
# #################################
#  new best 259.5898495230441 saving Q...
# #################################
# iteration=0 epoch=8 Average Reward per episode: 474.40695661309326
# #################################
#  new best 474.40695661309326 saving Q...
# #################################
# iteration=0 epoch=9 Average Reward per episode: 295.2883132577902
# loading best result
# rollout iteration 1 with epsilon=92.86%...
# starting training on rollout information...
# iteration=1 epoch=0 Average Reward per episode: -194.0737521161906
# iteration=1 epoch=1 Average Reward per episode: -96.4480835668337
# iteration=1 epoch=2 Average Reward per episode: -25.999708888852474
# iteration=1 epoch=3 Average Reward per episode: 711.3218697393733
# #################################
#  new best 711.3218697393733 saving Q...
# #################################
# iteration=1 epoch=4 Average Reward per episode: -339.7653068500091
# iteration=1 epoch=5 Average Reward per episode: -574.0267258898433
# iteration=1 epoch=6 Average Reward per episode: -424.2359788268899
# iteration=1 epoch=7 Average Reward per episode: -475.50979457247485
# iteration=1 epoch=8 Average Reward per episode: -530.6243700636709
# iteration=1 epoch=9 Average Reward per episode: -585.9856955465033
# loading best result
# rollout iteration 2 with epsilon=85.71%...
# starting training on rollout information...
# iteration=2 epoch=0 Average Reward per episode: 89.6292001641111
# iteration=2 epoch=1 Average Reward per episode: -533.585537776519
# iteration=2 epoch=2 Average Reward per episode: -415.9562854470011
# iteration=2 epoch=3 Average Reward per episode: -349.0423752237933
# iteration=2 epoch=4 Average Reward per episode: -382.1746244665595
# iteration=2 epoch=5 Average Reward per episode: -495.55370067043367
# iteration=2 epoch=6 Average Reward per episode: -502.55855272239535
# iteration=2 epoch=7 Average Reward per episode: -492.1625810381489
# iteration=2 epoch=8 Average Reward per episode: -383.3983742580364
# iteration=2 epoch=9 Average Reward per episode: -511.98634252071935
# loading best result
# rollout iteration 3 with epsilon=78.57%...
# starting training on rollout information...
# iteration=3 epoch=0 Average Reward per episode: 16.57494567606826
# iteration=3 epoch=1 Average Reward per episode: 104.99082826630868
# iteration=3 epoch=2 Average Reward per episode: -37.57033296136693
# iteration=3 epoch=3 Average Reward per episode: -47.12488305028022
# iteration=3 epoch=4 Average Reward per episode: -46.92872960320948
# iteration=3 epoch=5 Average Reward per episode: 309.6259973249416
# iteration=3 epoch=6 Average Reward per episode: -45.1588493341656
# iteration=3 epoch=7 Average Reward per episode: 297.55929295651646
# iteration=3 epoch=8 Average Reward per episode: 271.9833255185449
# iteration=3 epoch=9 Average Reward per episode: -225.00049346835166
# loading best result
# rollout iteration 4 with epsilon=71.43%...
# starting training on rollout information...
# iteration=4 epoch=0 Average Reward per episode: -18.827531812162412
# iteration=4 epoch=1 Average Reward per episode: -37.61710651167506
# iteration=4 epoch=2 Average Reward per episode: -37.587676742108464
# iteration=4 epoch=3 Average Reward per episode: -37.5750978048974
# iteration=4 epoch=4 Average Reward per episode: -46.026926870155236
# iteration=4 epoch=5 Average Reward per episode: -47.12530178822006
# iteration=4 epoch=6 Average Reward per episode: -47.11985850218595
# iteration=4 epoch=7 Average Reward per episode: -47.12864770557553
# iteration=4 epoch=8 Average Reward per episode: -37.60381763181965
# iteration=4 epoch=9 Average Reward per episode: -37.62380783884531
# loading best result
# rollout iteration 5 with epsilon=64.29%...
# starting training on rollout information...
# iteration=5 epoch=0 Average Reward per episode: -35.40594826892124
# iteration=5 epoch=1 Average Reward per episode: -37.61166509796309
# iteration=5 epoch=2 Average Reward per episode: -37.57516756598069
# iteration=5 epoch=3 Average Reward per episode: -37.60527855707314
# iteration=5 epoch=4 Average Reward per episode: -36.10601544139733
# iteration=5 epoch=5 Average Reward per episode: -47.12231991091243
# iteration=5 epoch=6 Average Reward per episode: -47.12537233493397
# iteration=5 epoch=7 Average Reward per episode: -47.12564797012503
# iteration=5 epoch=8 Average Reward per episode: -47.12312241828237
# iteration=5 epoch=9 Average Reward per episode: -47.127385541019855
# loading best result
# rollout iteration 6 with epsilon=57.14%...
# starting training on rollout information...
# iteration=6 epoch=0 Average Reward per episode: -37.5944670156283
# iteration=6 epoch=1 Average Reward per episode: -37.6002901076716
# iteration=6 epoch=2 Average Reward per episode: -37.54441662693218
# iteration=6 epoch=3 Average Reward per episode: -37.562086468117045
# iteration=6 epoch=4 Average Reward per episode: -37.60184471587122
# iteration=6 epoch=5 Average Reward per episode: -37.58066376752711
# iteration=6 epoch=6 Average Reward per episode: -37.559603040843314
# iteration=6 epoch=7 Average Reward per episode: -37.58230400467511
# iteration=6 epoch=8 Average Reward per episode: -37.598860843610666
# iteration=6 epoch=9 Average Reward per episode: -37.60796035659018
# loading best result
# rollout iteration 7 with epsilon=50.00%...
# starting training on rollout information...
# iteration=7 epoch=0 Average Reward per episode: -37.62396020824095
# iteration=7 epoch=1 Average Reward per episode: -37.5844830046403
# iteration=7 epoch=2 Average Reward per episode: -37.607800399925125
# iteration=7 epoch=3 Average Reward per episode: -37.6408755734065
# iteration=7 epoch=4 Average Reward per episode: -37.62168387322816
# iteration=7 epoch=5 Average Reward per episode: -37.609673255343125
# iteration=7 epoch=6 Average Reward per episode: -37.61949659385674
# iteration=7 epoch=7 Average Reward per episode: -37.63606019501061
# iteration=7 epoch=8 Average Reward per episode: -37.60369657059081
# iteration=7 epoch=9 Average Reward per episode: -37.64397154040714
# loading best result
# rollout iteration 8 with epsilon=42.86%...
# starting training on rollout information...
# iteration=8 epoch=0 Average Reward per episode: -37.595912646905916
# iteration=8 epoch=1 Average Reward per episode: -37.61008544522018
# iteration=8 epoch=2 Average Reward per episode: -37.613403954954414
# iteration=8 epoch=3 Average Reward per episode: -37.61309705067531
# iteration=8 epoch=4 Average Reward per episode: -37.6039706685435
# iteration=8 epoch=5 Average Reward per episode: -37.607134476990375
# iteration=8 epoch=6 Average Reward per episode: -37.61861729510807
# iteration=8 epoch=7 Average Reward per episode: -37.57549881306257
# iteration=8 epoch=8 Average Reward per episode: -37.5761369138613
# iteration=8 epoch=9 Average Reward per episode: -37.619443224747144
# loading best result
# rollout iteration 9 with epsilon=35.71%...
# starting training on rollout information...
# iteration=9 epoch=0 Average Reward per episode: -37.56207402384673
# iteration=9 epoch=1 Average Reward per episode: -37.622958552728974
# iteration=9 epoch=2 Average Reward per episode: -37.6460648524164
# iteration=9 epoch=3 Average Reward per episode: -37.61215210706917
# iteration=9 epoch=4 Average Reward per episode: -37.62773860154779
# iteration=9 epoch=5 Average Reward per episode: -37.60791372960905
# iteration=9 epoch=6 Average Reward per episode: -37.59373459272869
# iteration=9 epoch=7 Average Reward per episode: -37.5939750448435
# iteration=9 epoch=8 Average Reward per episode: -37.601996558407606
# iteration=9 epoch=9 Average Reward per episode: -37.579669876417896
# loading best result
# rollout iteration 10 with epsilon=28.57%...
# starting training on rollout information...
# iteration=10 epoch=0 Average Reward per episode: -37.61212106543469
# iteration=10 epoch=1 Average Reward per episode: -37.64345398229117
# iteration=10 epoch=2 Average Reward per episode: -37.617731449641695
# iteration=10 epoch=3 Average Reward per episode: -37.603917714604925
# iteration=10 epoch=4 Average Reward per episode: -37.59908355716578
# iteration=10 epoch=5 Average Reward per episode: -37.61747778329528
# iteration=10 epoch=6 Average Reward per episode: -37.61421887940261
# iteration=10 epoch=7 Average Reward per episode: -37.59899818041742
# iteration=10 epoch=8 Average Reward per episode: -37.624594223947135
# iteration=10 epoch=9 Average Reward per episode: -37.60696901973181
# loading best result
# rollout iteration 11 with epsilon=21.43%...
# starting training on rollout information...
# iteration=11 epoch=0 Average Reward per episode: -37.6168871481285
# iteration=11 epoch=1 Average Reward per episode: -37.63550029374629
# iteration=11 epoch=2 Average Reward per episode: -37.583240329590474
# iteration=11 epoch=3 Average Reward per episode: -37.6124928711806
# iteration=11 epoch=4 Average Reward per episode: -37.59364337368874
# iteration=11 epoch=5 Average Reward per episode: -37.62065677288976
# iteration=11 epoch=6 Average Reward per episode: -37.61526558629056
# iteration=11 epoch=7 Average Reward per episode: -37.58669778474548
# iteration=11 epoch=8 Average Reward per episode: -37.53613999578742
# iteration=11 epoch=9 Average Reward per episode: -37.634660106036335
# loading best result
# rollout iteration 12 with epsilon=14.29%...
# starting training on rollout information...
# iteration=12 epoch=0 Average Reward per episode: -37.59796698189159
# iteration=12 epoch=1 Average Reward per episode: -37.60270257686392
# iteration=12 epoch=2 Average Reward per episode: -37.59255801199498
# iteration=12 epoch=3 Average Reward per episode: -37.58511381849037
# iteration=12 epoch=4 Average Reward per episode: -37.5826141697409
# iteration=12 epoch=5 Average Reward per episode: -37.56608604280761
# iteration=12 epoch=6 Average Reward per episode: -37.60600235041448
# iteration=12 epoch=7 Average Reward per episode: -37.59754851945071
# iteration=12 epoch=8 Average Reward per episode: -37.59238256133837
# iteration=12 epoch=9 Average Reward per episode: -37.61107684737588
# loading best result
# rollout iteration 13 with epsilon=7.14%...
# starting training on rollout information...
# iteration=13 epoch=0 Average Reward per episode: -37.600218501808094
# iteration=13 epoch=1 Average Reward per episode: -37.611310976664285
# iteration=13 epoch=2 Average Reward per episode: -37.60555343665554
# iteration=13 epoch=3 Average Reward per episode: -37.629268400591044
# iteration=13 epoch=4 Average Reward per episode: -37.62246141225183
# iteration=13 epoch=5 Average Reward per episode: -37.60938350530367
# iteration=13 epoch=6 Average Reward per episode: -37.56246267813013
# iteration=13 epoch=7 Average Reward per episode: -37.61554180306838
# iteration=13 epoch=8 Average Reward per episode: -37.61049130713597
# iteration=13 epoch=9 Average Reward per episode: -37.60756563201454
# loading best result
# rollout iteration 14 with epsilon=0.00%...
# starting training on rollout information...
# iteration=14 epoch=0 Average Reward per episode: -37.62751933151925
# iteration=14 epoch=1 Average Reward per episode: -37.61006017279082
# iteration=14 epoch=2 Average Reward per episode: -37.587688286274854
# iteration=14 epoch=3 Average Reward per episode: -37.61645125770788
# iteration=14 epoch=4 Average Reward per episode: -37.555906792731356
# iteration=14 epoch=5 Average Reward per episode: -37.615684831732025
# iteration=14 epoch=6 Average Reward per episode: -37.60493066749062
# iteration=14 epoch=7 Average Reward per episode: -37.60459511046488
# iteration=14 epoch=8 Average Reward per episode: -37.63399419665069
# iteration=14 epoch=9 Average Reward per episode: -37.606611898569994
# loading best result
# loading best result

# %%
# # reward_function =  lambda self: np.exp(-(self.th%(2*np.pi)-np.pi)**2/(2*(np.pi/7)**2))
# # reward_function =  lambda self: (np.cos(self.th - target_angle)+1)**2  - np.cos(self.th-(np.pi+target_angle)) - 0.01*(self.omega)**2 - 0.01*(self.u)**2
# # reward_function =  lambda self: ((np.cos(self.th-target_angle)+1.5)**2 - 0.25) + 0.00125*(((np.cos(self.th)+1)/2)*(self.omega)**2) - 0.0075*((self.u)**2) - 0.0025*((self.omega)**2)

# # Washing machine (Qfunction2)
# # reward_function = lambda self: np.exp(-(self.th % (2 * np.pi) - np.pi) ** 2 / (2 * (np.pi / 7) ** 2)) + (1.0 if np.abs(self.th % (2 * np.pi) - np.pi) < np.pi / 2 else 0.0) - 0.001 * self.u ** 2
# # stuck at u=3
# # reward_function = lambda self: ((np.cos(self.th-target_angle)+1.6)** 2 - 0.25) - 0.0025*(self.omega)** 2 - 0.0075*(self.u)**2

# # reward_function = lambda self: np.exp(-(self.th % (2 * np.pi) - np.pi) ** 2 / (2 * (np.pi / 7) ** 2)) + (1.0 if np.abs(self.th % (2 * np.pi) - np.pi) < np.pi / 2 else -0.5) - 0.001 * self.u ** 2

# # Yann best
# reward_function =  lambda self: ((np.cos(self.th-target_angle)+1.5)**2 - 0.25) + 0.00125*(((np.cos(self.th)+1)/2)*(self.omega)**2) - 0.01*((self.u)**2)

# %%
u,theta,omega = show(Q,env)
# Out:
# pygame 2.4.0 (SDL 2.26.4, Python 3.8.16)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
target_angle = np.pi # target set to be balanced on top

# Create a figure with three subplots
fig, axs = plt.subplots(1, 3, figsize=(12, 4))

# Plot theta
axs[0].plot([i*env.dt for i in range(max_episode_steps)], theta, '.')
axs[0].set_title('Theta')
axs[0].set_xlabel('Time (s)')
axs[0].set_ylabel('Angle (Rad)')
axs[0].axhline(y=target_angle, color='r', linestyle='-')
axs[0].axhline(y=-target_angle, color='r', linestyle='-')
axs[0].grid(True)

# Plot u
axs[1].plot([i*env.dt for i in range(max_episode_steps)], u, '.')
axs[1].set_title('u')
axs[1].set_xlabel('Time (s)')
axs[1].set_ylabel('Input voltage (V)')
axs[1].grid(True)

# Plot omega
axs[2].plot([i*env.dt for i in range(max_episode_steps)], omega, '.')
axs[2].set_title('Omega')
axs[2].set_xlabel('Time (s)')
axs[2].set_ylabel('Angular velocity (rad/s)')
axs[2].grid(True)

# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Save Q to a file
date = datetime.datetime.now().strftime("%d_%H_%M")
torch.save(Q.state_dict(), 'Qfunction' + date + '.pt')

# %%
eval_Q(Q,env)
# Out:
# 746.0947092746972

# %%
Rewards = [eval_Q(Q,env) for i in range(100)]
plt.plot(Rewards,'.')
plt.title(f'mean={np.mean(Rewards)}')
plt.xlabel('instance')
plt.ylabel('Reward per episode')
plt.show()

# %%
Rewards = [eval_Q(Q,env) for i in range(100)]
plt.plot(Rewards,'.')
plt.title(f'mean={np.mean(Rewards)}')
plt.xlabel('instance')
plt.ylabel('Reward per episode')
plt.ylim(np.min(Rewards)-2.5, np.max(Rewards)+2.5)
plt.axhline(y=np.mean(Rewards), color='r', linestyle='-')
plt.grid(True)
plt.show()

# %%
Q
# Out:
# Qfunction(
#   (lay1): Linear(in_features=3, out_features=40, bias=True)
#   (F1): Tanh()
#   (lay2): Linear(in_features=40, out_features=5, bias=True)
# )

# %%
env.action_space.n
# Out:
# 5
