# %%
import sys
sys.path.append('gym-unbalanced-disk/gym_unbalanced_disk/')
from torch import nn
import torch, gym, gym_unbalanced_disk, time, gym.wrappers
import numpy as np
from matplotlib import pyplot as plt
from copy import deepcopy
import os
import datetime

# %% [markdown]
# # QFUNCTION NOG AANPASSEN

# %%
class Qfunction(nn.Module):
    def __init__(self, env):
        super(Qfunction,self).__init__()
        self.lay1 = nn.Linear(env.observation_space.shape[0], 40)
        self.F1 =  nn.Tanh() #a)
        self.lay2 = nn.Linear(40,env.action_space.n)
    
    def forward(self, obs):
        return self.lay2(self.F1(self.lay1(obs)))

# %%
def show(Q,env):
    u = []
    theta = []
    omega = []
    with torch.no_grad():
        #you can use Qfun(obs) as a shorthand for the q function.
        Qfun = lambda x: Q(torch.tensor(x[None,:],dtype=torch.float32))[0].numpy() #convert x to torch.tensor -> put in the Q function -> back to numpy
        try:
            obs = env.reset() #b)
            env.render() #b)
            time.sleep(10) # give time to open window
            while True: #b)
                action = np.argmax(Qfun(obs)) #b)
                obs, reward, done, info = env.step(action) #b)
                time.sleep(1/60) #b)
                env.render() #b)
                u.append(env.u)
                theta.append(env.th)
                omega.append(env.omega)
                if done: #b)
                    time.sleep(0.5)  #b)
                    break  #b)
        finally: #this will always run even when an error occurs
            env.close()
            return u,theta,omega

# %%
def rollout(Q, env, epsilon=0.1, N_rollout=10_000): 
    #save the following (use .append)
    Start_state = [] #hold an array of (x_t)
    Actions = [] #hold an array of (u_t)
    Rewards = [] #hold an array of (r_{t+1})
    End_state = [] #hold an array of (x_{t+1})
    Terminal = [] #hold an array of (terminal_{t+1})
    # Qfun( a numpy array of the obs) -> a numpy array of Q values
    Qfun = lambda x: Q(torch.tensor(x[None,:],dtype=torch.float32))[0].numpy() 
    with torch.no_grad():
        
        obs = env.reset() #c)
        for i in range(N_rollout): #c)
            if np.random.uniform()>epsilon: #c)
                Qnow = Qfun(obs) #c)
                action = np.argmax(Qnow) #c)
            else: #c)
                action = env.action_space.sample() #c)
            Start_state.append(obs) #c)
            Actions.append(action) #c)

            obs_next, reward, done, info = env.step(action) #c)
            terminal = done and not info.get('TimeLimit.truncated', False) #c)

            Terminal.append(terminal) #c)
            Rewards.append(reward) #c)
            End_state.append(obs_next) #c)

            if done: #c)
                obs = env.reset() #c)
            else: #c)
                obs = obs_next #c)
                
    #error checking:
    assert len(Start_state)==len(Actions)==len(Rewards)==len(End_state)==len(Terminal), f'error in lengths: {len(Start_state)}=={len(Actions)}=={len(Rewards)}=={len(End_state)}=={len(Dones)}'
    return np.array(Start_state), np.array(Actions), np.array(Rewards), np.array(End_state), np.array(Terminal).astype(int)

# %%
def eval_Q(Q,env):
    with torch.no_grad():
        Qfun = lambda x: Q(torch.tensor(x[None,:],dtype=torch.float32))[0].numpy()
        rewards_acc = 0 #d)
        obs = env.reset() #d)
        while True: #d)
            action = np.argmax(Qfun(obs)) #d)
            obs, reward, done, info = env.step(action) #d)
            rewards_acc += reward #d)
            if done: #d)
                return rewards_acc #d)

# %%
def DQN_rollout(Q, optimizer, env, gamma=0.98, use_target_net=False, N_iterations=21, N_rollout=20000, \
                N_epochs=10, batch_size=32, N_evals=10, target_net_update_feq=100):
    best = -float('inf')
    torch.save(Q.state_dict(),'Q-checkpoint')
    try:
        for iteration in range(N_iterations):
            epsilon = 1.0 - iteration/(N_iterations-1) #e=) 1.
            print(f'rollout iteration {iteration} with epsilon={epsilon:.2%}...')
            
            #2. rollout
            Start_state, Actions, Rewards, End_state, Dones = rollout(Q, env, epsilon=epsilon, N_rollout=N_rollout) #e) 2.
            
            #Data conversion, no changes required
            convert = lambda x: [torch.tensor(xi,dtype=torch.float32) for xi in x]
            Start_state, Rewards, End_state, Dones = convert([Start_state, Rewards, End_state, Dones])
            Actions = Actions.astype(int)

            print('starting training on rollout information...')
            t = 0
            for epoch in range(N_epochs): 
                for i in range(batch_size,len(Start_state)+1,batch_size): 
                    if t%target_net_update_feq==0:
                        Qtarget = deepcopy(Q) #g)
                        pass
                    t += 1
                    
                    Start_state_batch, Actions_batch, Rewards_batch, End_state_batch, Dones_batch = [d[i-batch_size:i] for d in [Start_state, Actions, Rewards, End_state, Dones]] #e=) 3.
                    
                    with torch.no_grad(): #3.
                        if use_target_net:
                            maxQ = torch.max(Qtarget(End_state_batch),dim=1)[0] #g)
                        else:
                            maxQ = torch.max(Q(End_state_batch),dim=1)[0] #e=) 3.
                    
                    action_index = np.stack((np.arange(batch_size),Actions_batch),axis=0)
                    Qnow = Q(Start_state_batch)[action_index] #Q(x_t,u_t) is given
                    
                    Loss = torch.mean((Rewards_batch + gamma*maxQ*(1-Dones_batch) - Qnow)**2) #e) 3.
                    optimizer.zero_grad() #e) 3.
                    Loss.backward() #e) 3.
                    optimizer.step() #e) 3.
                
                score = np.mean([eval_Q(Q,env) for i in range(N_evals)]) #e=) 3.
                
                print(f'iteration={iteration} epoch={epoch} Average Reward per episode:',score)
                if score>best:
                    best = score
                    print('################################# \n new best',best,'saving Q... \n#################################')
                    torch.save(Q.state_dict(),'Q-checkpoint6')
            
            print('loading best result')
            Q.load_state_dict(torch.load('Q-checkpoint6'))
    finally: #this will always run even when using the a KeyBoard Interrupt. 
        print('loading best result')
        Q.load_state_dict(torch.load('Q-checkpoint6'))

# %%
target_angle = np.pi # target set to be balanced on top

# %%
max_voltage = 3.0  # Maximum allowable voltage
max_angular_velocity = np.pi  # Maximum allowable angular velocity (radians per second)

Angle_reward = lambda self: 10*(np.cos(self.th - target_angle))
Velocity_reward = lambda self: (1.0 - np.tanh(abs(self.omega / max_angular_velocity)))
Voltage_penalty = lambda self: -0.001 * ((max(abs(self.u) - max_voltage, 0)) ** 2)
Angle_penalty = lambda self: -0.01 * abs(self.th - target_angle)

reward_function = lambda self: Angle_reward(self) + Velocity_reward(self) + Voltage_penalty(self) + Angle_penalty(self)

max_episode_steps = 300
gamma = 0.98
batch_size = 40
N_iterations = 25
N_rollout = 20000
N_epochs = 10
N_evals = 5
lr = 0.0005

# %%
env = gym.make('unbalanced-disk-sincos-v0', dt=0.025, umax=3.)
env = gym.wrappers.time_limit.TimeLimit(env,max_episode_steps=max_episode_steps)
env.change_reward_function(reward_function)
# Out:
# Running from folder

# %%
env.set_discrete_values(discrete_size = 9, minmax = 3.0, div = 2.5, rnd = 2)
# env.set_discrete_values_manual([-3.0, -1.5, -0.75, -0.5, -0.25, -0.15, -0.1, 0, 0.1, 0.15, 0.25, 0.5, 0.75, 1.5, 3.0])
# Out:
# Discrete value set changed to [-3.0, -1.2, -0.48, -0.19, 0, 0.19, 0.48, 1.2, 3.0]

# %%
assert isinstance(env.action_space,gym.spaces.Discrete), 'action space requires to be discrete'
Q = Qfunction(env)
optimizer = torch.optim.Adam(Q.parameters(),lr=lr) #low learning rate
DQN_rollout(Q, optimizer, env, use_target_net=True, gamma=gamma, N_iterations=N_iterations, \
            N_rollout=N_rollout, N_epochs=N_epochs, N_evals=N_evals)
# Out:
# rollout iteration 0 with epsilon=100.00%...
# starting training on rollout information...
# iteration=0 epoch=0 Average Reward per episode: -2057.3027556876596
# #################################
#  new best -2057.3027556876596 saving Q...
# #################################
# iteration=0 epoch=1 Average Reward per episode: -1945.7162254780033
# #################################
#  new best -1945.7162254780033 saving Q...
# #################################
# iteration=0 epoch=2 Average Reward per episode: -1945.6685151929978
# #################################
#  new best -1945.6685151929978 saving Q...
# #################################
# iteration=0 epoch=3 Average Reward per episode: -1945.6689114346234
# iteration=0 epoch=4 Average Reward per episode: -1945.2062014501128
# #################################
#  new best -1945.2062014501128 saving Q...
# #################################
# iteration=0 epoch=5 Average Reward per episode: -1945.7919445357668
# iteration=0 epoch=6 Average Reward per episode: -1945.2301140695854
# iteration=0 epoch=7 Average Reward per episode: -1946.056648726911
# iteration=0 epoch=8 Average Reward per episode: -1945.377141696803
# iteration=0 epoch=9 Average Reward per episode: -1945.9732940756335
# loading best result
# rollout iteration 1 with epsilon=95.83%...
# starting training on rollout information...
# iteration=1 epoch=0 Average Reward per episode: -2709.4838255747673
# iteration=1 epoch=1 Average Reward per episode: -2709.4845915770484
# iteration=1 epoch=2 Average Reward per episode: -2693.83029281964
# iteration=1 epoch=3 Average Reward per episode: -2693.8692145878936
# iteration=1 epoch=4 Average Reward per episode: -2693.808016555819
# iteration=1 epoch=5 Average Reward per episode: -2693.906800601116
# iteration=1 epoch=6 Average Reward per episode: -2693.974347824397
# iteration=1 epoch=7 Average Reward per episode: -2693.883400417408
# iteration=1 epoch=8 Average Reward per episode: -2693.7991306752915
# iteration=1 epoch=9 Average Reward per episode: -2694.0199373491014
# loading best result
# rollout iteration 2 with epsilon=91.67%...
# starting training on rollout information...
# iteration=2 epoch=0 Average Reward per episode: -2621.7458981935997
# iteration=2 epoch=1 Average Reward per episode: -2693.941935424961
# iteration=2 epoch=2 Average Reward per episode: -2621.679974203292
# iteration=2 epoch=3 Average Reward per episode: -2693.9497561713624
# iteration=2 epoch=4 Average Reward per episode: -2693.916396153865
# iteration=2 epoch=5 Average Reward per episode: -2694.0240550666963
# iteration=2 epoch=6 Average Reward per episode: -2694.0587327912212
# iteration=2 epoch=7 Average Reward per episode: -2694.024647539187
# iteration=2 epoch=8 Average Reward per episode: -2693.98087332955
# iteration=2 epoch=9 Average Reward per episode: -2693.9862045968625
# loading best result
# rollout iteration 3 with epsilon=87.50%...
# starting training on rollout information...
# iteration=3 epoch=0 Average Reward per episode: -2693.9116410536467
# iteration=3 epoch=1 Average Reward per episode: -2693.9430541896663
# iteration=3 epoch=2 Average Reward per episode: -2621.6356234435166
# iteration=3 epoch=3 Average Reward per episode: -2621.563712476313
# iteration=3 epoch=4 Average Reward per episode: -2621.772690577638
# iteration=3 epoch=5 Average Reward per episode: -2621.498812039271
# iteration=3 epoch=6 Average Reward per episode: -2621.7251616925723
# iteration=3 epoch=7 Average Reward per episode: -2621.625536828731
# iteration=3 epoch=8 Average Reward per episode: -2621.6224934220545
# iteration=3 epoch=9 Average Reward per episode: -2621.586249611546
# loading best result
# rollout iteration 4 with epsilon=83.33%...
# starting training on rollout information...
# iteration=4 epoch=0 Average Reward per episode: -2621.1758045595857
# iteration=4 epoch=1 Average Reward per episode: -2621.911970139091
# iteration=4 epoch=2 Average Reward per episode: -2709.474191352296
# iteration=4 epoch=3 Average Reward per episode: -2709.476245306473
# iteration=4 epoch=4 Average Reward per episode: -2709.4708871180155
# iteration=4 epoch=5 Average Reward per episode: -2709.4781277135116
# iteration=4 epoch=6 Average Reward per episode: -2709.467120127813
# iteration=4 epoch=7 Average Reward per episode: -2709.508707300974
# iteration=4 epoch=8 Average Reward per episode: -2709.489379671534
# iteration=4 epoch=9 Average Reward per episode: -2709.5011846922303
# loading best result
# rollout iteration 5 with epsilon=79.17%...
# starting training on rollout information...
# iteration=5 epoch=0 Average Reward per episode: -2709.5043014299927
# iteration=5 epoch=1 Average Reward per episode: -2709.5058735629946
# iteration=5 epoch=2 Average Reward per episode: -2709.508523857435
# iteration=5 epoch=3 Average Reward per episode: -2709.511151107223
# iteration=5 epoch=4 Average Reward per episode: -2709.4992813840295
# iteration=5 epoch=5 Average Reward per episode: -2709.5023455996343
# iteration=5 epoch=6 Average Reward per episode: -2709.5121820877284
# iteration=5 epoch=7 Average Reward per episode: -2709.5053522213952
# iteration=5 epoch=8 Average Reward per episode: -2693.681141524031
# iteration=5 epoch=9 Average Reward per episode: -2693.9367582144455
# loading best result
# rollout iteration 6 with epsilon=75.00%...
# starting training on rollout information...
# iteration=6 epoch=0 Average Reward per episode: -2693.8835533009415
# iteration=6 epoch=1 Average Reward per episode: -2694.1200965034777
# iteration=6 epoch=2 Average Reward per episode: -2693.9947330603964
# iteration=6 epoch=3 Average Reward per episode: -2694.5368035047877
# iteration=6 epoch=4 Average Reward per episode: -2694.746361873901
# iteration=6 epoch=5 Average Reward per episode: -2694.366268915209
# iteration=6 epoch=6 Average Reward per episode: -2694.485576979362
# iteration=6 epoch=7 Average Reward per episode: -2694.5843961409164
# iteration=6 epoch=8 Average Reward per episode: -2694.497898526447
# iteration=6 epoch=9 Average Reward per episode: -2694.557085086091
# loading best result
# rollout iteration 7 with epsilon=70.83%...
# starting training on rollout information...
# iteration=7 epoch=0 Average Reward per episode: -2694.6535385701827
# iteration=7 epoch=1 Average Reward per episode: -2694.642908567507
# iteration=7 epoch=2 Average Reward per episode: -2694.632471481364
# iteration=7 epoch=3 Average Reward per episode: -2694.6191691308495
# iteration=7 epoch=4 Average Reward per episode: -2694.7184238247487
# iteration=7 epoch=5 Average Reward per episode: -2709.5014979070206
# iteration=7 epoch=6 Average Reward per episode: -2709.5079788077583
# iteration=7 epoch=7 Average Reward per episode: -2709.5076507868575
# iteration=7 epoch=8 Average Reward per episode: -2709.4957069227958
# iteration=7 epoch=9 Average Reward per episode: -2709.5029429813685
# loading best result
# rollout iteration 8 with epsilon=66.67%...
# starting training on rollout information...
# iteration=8 epoch=0 Average Reward per episode: -2709.504898054172
# iteration=8 epoch=1 Average Reward per episode: -2709.495646730708
# iteration=8 epoch=2 Average Reward per episode: -2709.494248453436
# iteration=8 epoch=3 Average Reward per episode: -2709.517819428106
# iteration=8 epoch=4 Average Reward per episode: -2709.50154113203
# iteration=8 epoch=5 Average Reward per episode: -2709.5138774528996
# iteration=8 epoch=6 Average Reward per episode: -2709.5055797835003
# iteration=8 epoch=7 Average Reward per episode: -2709.5005286796786
# iteration=8 epoch=8 Average Reward per episode: -2709.50063217696
# iteration=8 epoch=9 Average Reward per episode: -2709.500452722845
# loading best result
# rollout iteration 9 with epsilon=62.50%...
# starting training on rollout information...
# iteration=9 epoch=0 Average Reward per episode: -2709.5094913532566
# iteration=9 epoch=1 Average Reward per episode: -1941.0922170485405
# #################################
#  new best -1941.0922170485405 saving Q...
# #################################
# iteration=9 epoch=2 Average Reward per episode: -1941.2360369326666
# iteration=9 epoch=3 Average Reward per episode: -1941.2444103344508
# iteration=9 epoch=4 Average Reward per episode: -1941.5149739119229
# iteration=9 epoch=5 Average Reward per episode: -1941.4899080124665
# iteration=9 epoch=6 Average Reward per episode: -1941.3823117759318
# iteration=9 epoch=7 Average Reward per episode: -1941.8440132487217
# iteration=9 epoch=8 Average Reward per episode: -2621.5531668209196
# iteration=9 epoch=9 Average Reward per episode: -2621.6505112948935
# loading best result
# rollout iteration 10 with epsilon=58.33%...
# starting training on rollout information...
# iteration=10 epoch=0 Average Reward per episode: -1945.9182145448926
# iteration=10 epoch=1 Average Reward per episode: -1946.2598435370298
# iteration=10 epoch=2 Average Reward per episode: -1945.5887641144213
# iteration=10 epoch=3 Average Reward per episode: -1946.078964758371
# iteration=10 epoch=4 Average Reward per episode: -1945.8041137818982
# iteration=10 epoch=5 Average Reward per episode: -2709.4732563775788
# iteration=10 epoch=6 Average Reward per episode: -2709.4811638322853
# iteration=10 epoch=7 Average Reward per episode: -2709.4825037683154
# iteration=10 epoch=8 Average Reward per episode: -2709.477854551663
# iteration=10 epoch=9 Average Reward per episode: -2709.466534957856
# loading best result
# rollout iteration 11 with epsilon=54.17%...
# starting training on rollout information...
# iteration=11 epoch=0 Average Reward per episode: -2709.475298122156
# iteration=11 epoch=1 Average Reward per episode: -2709.471944473783
# iteration=11 epoch=2 Average Reward per episode: -2709.470164944648
# iteration=11 epoch=3 Average Reward per episode: -2709.478001396794
# iteration=11 epoch=4 Average Reward per episode: -2709.477762970309
# iteration=11 epoch=5 Average Reward per episode: -2709.4801905369654
# iteration=11 epoch=6 Average Reward per episode: -2709.4778454068974
# iteration=11 epoch=7 Average Reward per episode: -2709.473147201717
# iteration=11 epoch=8 Average Reward per episode: -2709.47542211882
# iteration=11 epoch=9 Average Reward per episode: -2709.4822144014256
# loading best result
# rollout iteration 12 with epsilon=50.00%...
# starting training on rollout information...
# iteration=12 epoch=0 Average Reward per episode: -2709.48582517259
# iteration=12 epoch=1 Average Reward per episode: -2621.471512154002
# iteration=12 epoch=2 Average Reward per episode: -2621.62341874741
# iteration=12 epoch=3 Average Reward per episode: -2621.4877134033686
# iteration=12 epoch=4 Average Reward per episode: -2621.695961737463
# iteration=12 epoch=5 Average Reward per episode: -2621.798993129508
# iteration=12 epoch=6 Average Reward per episode: -2622.0446107111075
# iteration=12 epoch=7 Average Reward per episode: -2621.7299529932375
# iteration=12 epoch=8 Average Reward per episode: -2622.019393893727
# iteration=12 epoch=9 Average Reward per episode: -2621.5011118563502
# loading best result
# rollout iteration 13 with epsilon=45.83%...
# starting training on rollout information...
# iteration=13 epoch=0 Average Reward per episode: -2621.6738407364346
# iteration=13 epoch=1 Average Reward per episode: -2622.017613784176
# iteration=13 epoch=2 Average Reward per episode: -2621.5445719024588
# iteration=13 epoch=3 Average Reward per episode: -2622.0756919993614
# iteration=13 epoch=4 Average Reward per episode: -2694.664900720799
# iteration=13 epoch=5 Average Reward per episode: -2694.595520910122
# iteration=13 epoch=6 Average Reward per episode: -2694.634656443804
# iteration=13 epoch=7 Average Reward per episode: -2694.5482946194693
# iteration=13 epoch=8 Average Reward per episode: -2694.627621688095
# iteration=13 epoch=9 Average Reward per episode: -2694.5954549546605
# loading best result
# rollout iteration 14 with epsilon=41.67%...
# starting training on rollout information...
# iteration=14 epoch=0 Average Reward per episode: -2709.502414113046
# iteration=14 epoch=1 Average Reward per episode: -2709.504947921847
# iteration=14 epoch=2 Average Reward per episode: -2709.5177653023793
# iteration=14 epoch=3 Average Reward per episode: -2709.506341873167
# iteration=14 epoch=4 Average Reward per episode: -2709.50604465668
# iteration=14 epoch=5 Average Reward per episode: -2709.5086014352314
# iteration=14 epoch=6 Average Reward per episode: -2709.4988066175024
# iteration=14 epoch=7 Average Reward per episode: -2709.508280674684
# iteration=14 epoch=8 Average Reward per episode: -2709.5079406410973
# iteration=14 epoch=9 Average Reward per episode: -2709.5000564552847
# loading best result
# rollout iteration 15 with epsilon=37.50%...
# starting training on rollout information...
# iteration=15 epoch=0 Average Reward per episode: -2709.502971420955
# iteration=15 epoch=1 Average Reward per episode: -2709.502381726044
# iteration=15 epoch=2 Average Reward per episode: -2709.4963891398074
# iteration=15 epoch=3 Average Reward per episode: -2709.5086891691326
# iteration=15 epoch=4 Average Reward per episode: -2694.5622527094033
# iteration=15 epoch=5 Average Reward per episode: -2694.6419766981567
# iteration=15 epoch=6 Average Reward per episode: -2694.628702736949
# iteration=15 epoch=7 Average Reward per episode: -2694.4503107218957
# iteration=15 epoch=8 Average Reward per episode: -2694.5357742646133
# iteration=15 epoch=9 Average Reward per episode: -2694.6232706649143
# loading best result
# rollout iteration 16 with epsilon=33.33%...
# starting training on rollout information...
# iteration=16 epoch=0 Average Reward per episode: -2709.503808929573
# iteration=16 epoch=1 Average Reward per episode: -2709.502824303574
# iteration=16 epoch=2 Average Reward per episode: -2709.507754236154
# iteration=16 epoch=3 Average Reward per episode: -2709.511483298402
# iteration=16 epoch=4 Average Reward per episode: -2709.502662243017
# iteration=16 epoch=5 Average Reward per episode: -2709.5014914090043
# iteration=16 epoch=6 Average Reward per episode: -2709.50959433123
# iteration=16 epoch=7 Average Reward per episode: -2709.510964835331
# iteration=16 epoch=8 Average Reward per episode: -2709.5028296153782
# iteration=16 epoch=9 Average Reward per episode: -2709.499781733681
# loading best result
# rollout iteration 17 with epsilon=29.17%...
# starting training on rollout information...
# iteration=17 epoch=0 Average Reward per episode: -2709.476467927081
# iteration=17 epoch=1 Average Reward per episode: -2709.471608866291
# iteration=17 epoch=2 Average Reward per episode: -2622.8806469364813
# iteration=17 epoch=3 Average Reward per episode: -2623.1311395538346
# iteration=17 epoch=4 Average Reward per episode: -2623.5546376970105
# iteration=17 epoch=5 Average Reward per episode: -2694.5558319120546
# iteration=17 epoch=6 Average Reward per episode: -2694.5680131337017
# iteration=17 epoch=7 Average Reward per episode: -2694.386806354026
# iteration=17 epoch=8 Average Reward per episode: -2694.4957922076155
# iteration=17 epoch=9 Average Reward per episode: -2694.4851571057234
# loading best result
# rollout iteration 18 with epsilon=25.00%...
# starting training on rollout information...
# iteration=18 epoch=0 Average Reward per episode: -2694.3598085871936
# iteration=18 epoch=1 Average Reward per episode: -2694.7205576370557
# iteration=18 epoch=2 Average Reward per episode: -2694.4278078342736
# iteration=18 epoch=3 Average Reward per episode: -2693.9403753910947
# iteration=18 epoch=4 Average Reward per episode: -2693.804808028674
# iteration=18 epoch=5 Average Reward per episode: -2693.994168149995
# iteration=18 epoch=6 Average Reward per episode: -2694.0237508350983
# iteration=18 epoch=7 Average Reward per episode: -2693.8893488747767
# iteration=18 epoch=8 Average Reward per episode: -2694.0839557071668
# iteration=18 epoch=9 Average Reward per episode: -2693.8597585126245
# loading best result
# rollout iteration 19 with epsilon=20.83%...
# starting training on rollout information...
# iteration=19 epoch=0 Average Reward per episode: -2693.8884161333563
# iteration=19 epoch=1 Average Reward per episode: -2693.966190253757
# iteration=19 epoch=2 Average Reward per episode: -2694.005099561
# iteration=19 epoch=3 Average Reward per episode: -2694.002353566758
# iteration=19 epoch=4 Average Reward per episode: -2709.5083949456293
# iteration=19 epoch=5 Average Reward per episode: -2622.826981309239
# iteration=19 epoch=6 Average Reward per episode: -2623.091508648596
# iteration=19 epoch=7 Average Reward per episode: -2622.8251693057264
# iteration=19 epoch=8 Average Reward per episode: -2623.1498570456893
# iteration=19 epoch=9 Average Reward per episode: -2623.4236886757794
# loading best result
# rollout iteration 20 with epsilon=16.67%...
# starting training on rollout information...
# iteration=20 epoch=0 Average Reward per episode: -2623.33134759058
# iteration=20 epoch=1 Average Reward per episode: -2623.189481014252
# iteration=20 epoch=2 Average Reward per episode: -2623.1093104360416
# iteration=20 epoch=3 Average Reward per episode: -2622.741140515859
# iteration=20 epoch=4 Average Reward per episode: -2623.0113624960304
# iteration=20 epoch=5 Average Reward per episode: -2623.2533017338624
# iteration=20 epoch=6 Average Reward per episode: -2623.326684274087
# iteration=20 epoch=7 Average Reward per episode: -1945.8923440016886
# iteration=20 epoch=8 Average Reward per episode: -1945.9464944954423
# iteration=20 epoch=9 Average Reward per episode: -1945.3789395735698
# loading best result
# rollout iteration 21 with epsilon=12.50%...
# starting training on rollout information...
# iteration=21 epoch=0 Average Reward per episode: -2709.463347436969
# iteration=21 epoch=1 Average Reward per episode: -2709.474067201485
# iteration=21 epoch=2 Average Reward per episode: -2709.4728805043414
# iteration=21 epoch=3 Average Reward per episode: -2709.472021471569
# iteration=21 epoch=4 Average Reward per episode: -2709.479463931724
# iteration=21 epoch=5 Average Reward per episode: -2709.475552108311
# iteration=21 epoch=6 Average Reward per episode: -2709.5080344412213
# iteration=21 epoch=7 Average Reward per episode: -2709.501704788522
# iteration=21 epoch=8 Average Reward per episode: -2709.4970051434925
# iteration=21 epoch=9 Average Reward per episode: -2709.504604843126
# loading best result
# rollout iteration 22 with epsilon=8.33%...
# starting training on rollout information...
# iteration=22 epoch=0 Average Reward per episode: -2709.496251433518
# iteration=22 epoch=1 Average Reward per episode: -2709.4968199301343
# iteration=22 epoch=2 Average Reward per episode: -2709.500679638021
# iteration=22 epoch=3 Average Reward per episode: -2709.508211991597
# iteration=22 epoch=4 Average Reward per episode: -2709.499340304378
# iteration=22 epoch=5 Average Reward per episode: -2709.5027366687837
# iteration=22 epoch=6 Average Reward per episode: -2709.503951229217
# iteration=22 epoch=7 Average Reward per episode: -2709.489238617802
# iteration=22 epoch=8 Average Reward per episode: -2709.505170420156
# iteration=22 epoch=9 Average Reward per episode: -2709.5001663376647
# loading best result
# rollout iteration 23 with epsilon=4.17%...
# starting training on rollout information...
# iteration=23 epoch=0 Average Reward per episode: -2709.504398149277
# iteration=23 epoch=1 Average Reward per episode: -2709.4959623038767
# iteration=23 epoch=2 Average Reward per episode: -2709.502075868388
# iteration=23 epoch=3 Average Reward per episode: -2709.502473128477
# iteration=23 epoch=4 Average Reward per episode: -2709.5048850398066
# iteration=23 epoch=5 Average Reward per episode: -2709.5002399766495
# iteration=23 epoch=6 Average Reward per episode: -2709.4874991839474
# iteration=23 epoch=7 Average Reward per episode: -2709.501365912226
# iteration=23 epoch=8 Average Reward per episode: -2709.4937756418003
# iteration=23 epoch=9 Average Reward per episode: -2709.504289535483
# loading best result
# rollout iteration 24 with epsilon=0.00%...
# starting training on rollout information...
# iteration=24 epoch=0 Average Reward per episode: -2709.4968900726167
# iteration=24 epoch=1 Average Reward per episode: -2709.496353932637
# iteration=24 epoch=2 Average Reward per episode: -2709.506741079312
# iteration=24 epoch=3 Average Reward per episode: -2709.5088864294116
# iteration=24 epoch=4 Average Reward per episode: -2709.5021518201565
# iteration=24 epoch=5 Average Reward per episode: -2709.4914897466683
# iteration=24 epoch=6 Average Reward per episode: -2709.5067452565936
# iteration=24 epoch=7 Average Reward per episode: -2709.509230653799
# iteration=24 epoch=8 Average Reward per episode: -2709.5017870321026
# iteration=24 epoch=9 Average Reward per episode: -2709.5096558135347
# loading best result
# loading best result

# %%
# # reward_function =  lambda self: np.exp(-(self.th%(2*np.pi)-np.pi)**2/(2*(np.pi/7)**2))
# # reward_function =  lambda self: (np.cos(self.th - target_angle)+1)**2  - np.cos(self.th-(np.pi+target_angle)) - 0.01*(self.omega)**2 - 0.01*(self.u)**2
# # reward_function =  lambda self: ((np.cos(self.th-target_angle)+1.5)**2 - 0.25) + 0.00125*(((np.cos(self.th)+1)/2)*(self.omega)**2) - 0.0075*((self.u)**2) - 0.0025*((self.omega)**2)

# # Washing machine (Qfunction2)
# # reward_function = lambda self: np.exp(-(self.th % (2 * np.pi) - np.pi) ** 2 / (2 * (np.pi / 7) ** 2)) + (1.0 if np.abs(self.th % (2 * np.pi) - np.pi) < np.pi / 2 else 0.0) - 0.001 * self.u ** 2
# # stuck at u=3
# # reward_function = lambda self: ((np.cos(self.th-target_angle)+1.6)** 2 - 0.25) - 0.0025*(self.omega)** 2 - 0.0075*(self.u)**2

# # reward_function = lambda self: np.exp(-(self.th % (2 * np.pi) - np.pi) ** 2 / (2 * (np.pi / 7) ** 2)) + (1.0 if np.abs(self.th % (2 * np.pi) - np.pi) < np.pi / 2 else -0.5) - 0.001 * self.u ** 2

# # Yann best
# reward_function =  lambda self: ((np.cos(self.th-target_angle)+1.5)**2 - 0.25) + 0.00125*(((np.cos(self.th)+1)/2)*(self.omega)**2) - 0.01*((self.u)**2)

# %%
u,theta,omega = show(Q,env)
# Out:
# pygame 2.4.0 (SDL 2.26.4, Python 3.8.16)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
target_angle = np.pi # target set to be balanced on top

# Create a figure with three subplots
fig, axs = plt.subplots(1, 3, figsize=(12, 4))

# Plot theta
axs[0].plot([i*env.dt for i in range(max_episode_steps)], theta, '-')
axs[0].set_title('Theta')
axs[0].set_xlabel('Time (s)')
axs[0].set_ylabel('Angle (Rad)')
axs[0].axhline(y=target_angle, color='r', linestyle='-')
axs[0].axhline(y=-target_angle, color='r', linestyle='-')
axs[0].grid(True)

# Plot u
axs[1].plot([i*env.dt for i in range(max_episode_steps)], u, '.')
axs[1].set_title('u')
axs[1].set_xlabel('Time (s)')
axs[1].set_ylabel('Input voltage (V)')
axs[1].grid(True)

# Plot omega
axs[2].plot([i*env.dt for i in range(max_episode_steps)], omega, '.')
axs[2].set_title('Omega')
axs[2].set_xlabel('Time (s)')
axs[2].set_ylabel('Angular velocity (rad/s)')
axs[2].grid(True)

# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Save Q to a file
date = datetime.datetime.now().strftime("%d_%H_%M")
torch.save(Q.state_dict(), 'Qfunction' + date + '.pt')

# %%
eval_Q(Q,env)
# Out:
# -1940.6931494227622

# %%
Rewards = [eval_Q(Q,env) for i in range(100)]
plt.plot(Rewards,'.')
plt.title(f'mean={np.mean(Rewards)}')
plt.xlabel('instance')
plt.ylabel('Reward per episode')
plt.show()

# %%
Rewards = [eval_Q(Q,env) for i in range(100)]
plt.plot(Rewards,'.')
plt.title(f'mean={np.mean(Rewards)}')
plt.xlabel('instance')
plt.ylabel('Reward per episode')
plt.ylim(np.min(Rewards)-2.5, np.max(Rewards)+2.5)
plt.axhline(y=np.mean(Rewards), color='r', linestyle='-')
plt.grid(True)
plt.show()

# %%
Q
# Out:
# Qfunction(
#   (lay1): Linear(in_features=3, out_features=40, bias=True)
#   (F1): Tanh()
#   (lay2): Linear(in_features=40, out_features=9, bias=True)
# )

# %%
env.action_space.n
# Out:
# 9
