# %%
import sys
sys.path.append('gym-unbalanced-disk/gym_unbalanced_disk/')
from torch import nn
import torch, gym, gym_unbalanced_disk, time, gym.wrappers
import numpy as np
from matplotlib import pyplot as plt
from copy import deepcopy
import os
import datetime

# %% [markdown]
# # QFUNCTION NOG AANPASSEN

# %%
class Qfunction(nn.Module):
    def __init__(self, env):
        super(Qfunction,self).__init__()
        self.lay1 = nn.Linear(env.observation_space.shape[0], 40)
        self.F1 =  nn.Tanh() #a)
        self.lay2 = nn.Linear(40,env.action_space.n)
    
    def forward(self, obs):
        return self.lay2(self.F1(self.lay1(obs)))

# %%
def show(Q,env):
    u = []
    theta = []
    omega = []
    with torch.no_grad():
        #you can use Qfun(obs) as a shorthand for the q function.
        Qfun = lambda x: Q(torch.tensor(x[None,:],dtype=torch.float32))[0].numpy() #convert x to torch.tensor -> put in the Q function -> back to numpy
        try:
            obs = env.reset() #b)
            env.render() #b)
            time.sleep(10) # give time to open window
            while True: #b)
                action = np.argmax(Qfun(obs)) #b)
                obs, reward, done, info = env.step(action) #b)
                time.sleep(1/60) #b)
                env.render() #b)
                u.append(env.u)
                theta.append(env.th)
                omega.append(env.omega)
                if done: #b)
                    time.sleep(0.5)  #b)
                    break  #b)
        finally: #this will always run even when an error occurs
            env.close()
            return u,theta,omega

# %%
def rollout(Q, env, epsilon=0.1, N_rollout=10_000): 
    #save the following (use .append)
    Start_state = [] #hold an array of (x_t)
    Actions = [] #hold an array of (u_t)
    Rewards = [] #hold an array of (r_{t+1})
    End_state = [] #hold an array of (x_{t+1})
    Terminal = [] #hold an array of (terminal_{t+1})
    # Qfun( a numpy array of the obs) -> a numpy array of Q values
    Qfun = lambda x: Q(torch.tensor(x[None,:],dtype=torch.float32))[0].numpy() 
    with torch.no_grad():
        
        obs = env.reset() #c)
        for i in range(N_rollout): #c)
            if np.random.uniform()>epsilon: #c)
                Qnow = Qfun(obs) #c)
                action = np.argmax(Qnow) #c)
            else: #c)
                action = env.action_space.sample() #c)
            Start_state.append(obs) #c)
            Actions.append(action) #c)

            obs_next, reward, done, info = env.step(action) #c)
            terminal = done and not info.get('TimeLimit.truncated', False) #c)

            Terminal.append(terminal) #c)
            Rewards.append(reward) #c)
            End_state.append(obs_next) #c)

            if done: #c)
                obs = env.reset() #c)
            else: #c)
                obs = obs_next #c)
                
    #error checking:
    assert len(Start_state)==len(Actions)==len(Rewards)==len(End_state)==len(Terminal), f'error in lengths: {len(Start_state)}=={len(Actions)}=={len(Rewards)}=={len(End_state)}=={len(Dones)}'
    return np.array(Start_state), np.array(Actions), np.array(Rewards), np.array(End_state), np.array(Terminal).astype(int)

# %%
def eval_Q(Q,env):
    with torch.no_grad():
        Qfun = lambda x: Q(torch.tensor(x[None,:],dtype=torch.float32))[0].numpy()
        rewards_acc = 0 #d)
        obs = env.reset() #d)
        while True: #d)
            action = np.argmax(Qfun(obs)) #d)
            obs, reward, done, info = env.step(action) #d)
            rewards_acc += reward #d)
            if done: #d)
                return rewards_acc #d)

# %%
def DQN_rollout(Q, optimizer, env, gamma=0.98, use_target_net=False, N_iterations=21, N_rollout=20000, \
                N_epochs=10, batch_size=32, N_evals=10, target_net_update_feq=100):
    best = -float('inf')
    torch.save(Q.state_dict(),'Q-checkpoint')
    try:
        for iteration in range(N_iterations):
            epsilon = 1.0 - iteration/(N_iterations-1) #e=) 1.
            print(f'rollout iteration {iteration} with epsilon={epsilon:.2%}...')
            
            #2. rollout
            Start_state, Actions, Rewards, End_state, Dones = rollout(Q, env, epsilon=epsilon, N_rollout=N_rollout) #e) 2.
            
            #Data conversion, no changes required
            convert = lambda x: [torch.tensor(xi,dtype=torch.float32) for xi in x]
            Start_state, Rewards, End_state, Dones = convert([Start_state, Rewards, End_state, Dones])
            Actions = Actions.astype(int)

            print('starting training on rollout information...')
            t = 0
            for epoch in range(N_epochs): 
                for i in range(batch_size,len(Start_state)+1,batch_size): 
                    if t%target_net_update_feq==0:
                        Qtarget = deepcopy(Q) #g)
                        pass
                    t += 1
                    
                    Start_state_batch, Actions_batch, Rewards_batch, End_state_batch, Dones_batch = [d[i-batch_size:i] for d in [Start_state, Actions, Rewards, End_state, Dones]] #e=) 3.
                    
                    with torch.no_grad(): #3.
                        if use_target_net:
                            maxQ = torch.max(Qtarget(End_state_batch),dim=1)[0] #g)
                        else:
                            maxQ = torch.max(Q(End_state_batch),dim=1)[0] #e=) 3.
                    
                    action_index = np.stack((np.arange(batch_size),Actions_batch),axis=0)
                    Qnow = Q(Start_state_batch)[action_index] #Q(x_t,u_t) is given
                    
                    Loss = torch.mean((Rewards_batch + gamma*maxQ*(1-Dones_batch) - Qnow)**2) #e) 3.
                    optimizer.zero_grad() #e) 3.
                    Loss.backward() #e) 3.
                    optimizer.step() #e) 3.
                
                score = np.mean([eval_Q(Q,env) for i in range(N_evals)]) #e=) 3.
                
                print(f'iteration={iteration} epoch={epoch} Average Reward per episode:',score)
                if score>best:
                    best = score
                    print('################################# \n new best',best,'saving Q... \n#################################')
                    torch.save(Q.state_dict(),'Q-checkpoint5')
            
            print('loading best result')
            Q.load_state_dict(torch.load('Q-checkpoint5'))
    finally: #this will always run even when using the a KeyBoard Interrupt. 
        print('loading best result')
        Q.load_state_dict(torch.load('Q-checkpoint5'))

# %%
target_angle = np.pi # target set to be balanced on top

# %%
angle_reward = lambda self: ((np.cos(self.th-target_angle)+1.5)**2 - 0.25)
correctVelocity_reward = lambda self: 0.00250*(((np.cos(self.th)+1)/2)*(self.omega)**2)
voltage_penalty = lambda self: -0.005*((self.u)**2)
incorrectAngle_penalty = lambda self: -0.05*np.abs(self.th-target_angle)

reward_function = lambda self: angle_reward(self) + correctVelocity_reward(self) + voltage_penalty(self) + incorrectAngle_penalty(self)

max_episode_steps = 300
gamma = 0.98
batch_size = 32
N_iterations = 25
N_rollout = 10000
N_epochs = 10
N_evals = 10
lr = 0.0005

# %%
env = gym.make('unbalanced-disk-sincos-v0', dt=0.025, umax=3.)
env = gym.wrappers.time_limit.TimeLimit(env,max_episode_steps=max_episode_steps)
env.change_reward_function(reward_function)
# Out:
# Running from folder

# %%
# env.set_discrete_values(discrete_size = 9, minmax = 3.0, div = 2.5, rnd = 2)
env.set_discrete_values_manual([-3.0, -1.5, -0.75, -0.5, -0.25, -0.15, -0.1, 0, 0.1, 0.15, 0.25, 0.5, 0.75, 1.5, 3.0])
# Out:
# Discrete value set changed to [-3.0, -1.5, -0.75, -0.5, -0.25, -0.15, -0.1, 0, 0.1, 0.15, 0.25, 0.5, 0.75, 1.5, 3.0]

# %%
assert isinstance(env.action_space,gym.spaces.Discrete), 'action space requires to be discrete'
Q = Qfunction(env)
optimizer = torch.optim.Adam(Q.parameters(),lr=lr) #low learning rate
DQN_rollout(Q, optimizer, env, use_target_net=True, gamma=gamma, N_iterations=N_iterations, \
            N_rollout=N_rollout, N_epochs=N_epochs, N_evals=N_evals)
# Out:
# rollout iteration 0 with epsilon=100.00%...
# starting training on rollout information...
# iteration=0 epoch=0 Average Reward per episode: -0.5294415956739371
# #################################
#  new best -0.5294415956739371 saving Q...
# #################################
# iteration=0 epoch=1 Average Reward per episode: -3.033382101746416
# iteration=0 epoch=2 Average Reward per episode: 19.68030859174366
# #################################
#  new best 19.68030859174366 saving Q...
# #################################
# iteration=0 epoch=3 Average Reward per episode: 39.99158470720384
# #################################
#  new best 39.99158470720384 saving Q...
# #################################
# iteration=0 epoch=4 Average Reward per episode: -122.91359955992513
# iteration=0 epoch=5 Average Reward per episode: 134.3229215704011
# #################################
#  new best 134.3229215704011 saving Q...
# #################################
# iteration=0 epoch=6 Average Reward per episode: 33.16306722441097
# iteration=0 epoch=7 Average Reward per episode: -18.835530995552396
# iteration=0 epoch=8 Average Reward per episode: 507.55065207924633
# #################################
#  new best 507.55065207924633 saving Q...
# #################################
# iteration=0 epoch=9 Average Reward per episode: 336.5369958945024
# loading best result
# rollout iteration 1 with epsilon=95.83%...
# starting training on rollout information...
# iteration=1 epoch=0 Average Reward per episode: 275.2758822875013
# iteration=1 epoch=1 Average Reward per episode: -690.3430916640655
# iteration=1 epoch=2 Average Reward per episode: -715.0770069807244
# iteration=1 epoch=3 Average Reward per episode: -715.1111000675186
# iteration=1 epoch=4 Average Reward per episode: -721.5381804037127
# iteration=1 epoch=5 Average Reward per episode: 526.5958829377707
# #################################
#  new best 526.5958829377707 saving Q...
# #################################
# iteration=1 epoch=6 Average Reward per episode: 38.51007020251923
# iteration=1 epoch=7 Average Reward per episode: 85.38124797635544
# iteration=1 epoch=8 Average Reward per episode: 440.07655756179736
# iteration=1 epoch=9 Average Reward per episode: 14.281574156761286
# loading best result
# rollout iteration 2 with epsilon=91.67%...
# starting training on rollout information...
# iteration=2 epoch=0 Average Reward per episode: 117.39967185078476
# iteration=2 epoch=1 Average Reward per episode: -30.062398338394296
# iteration=2 epoch=2 Average Reward per episode: -319.00097204494887
# iteration=2 epoch=3 Average Reward per episode: -128.7188285640661
# iteration=2 epoch=4 Average Reward per episode: -162.93377362694537
# iteration=2 epoch=5 Average Reward per episode: -54.89633551790181
# iteration=2 epoch=6 Average Reward per episode: -155.80226742444347
# iteration=2 epoch=7 Average Reward per episode: -267.8028811707272
# iteration=2 epoch=8 Average Reward per episode: -480.73351927224724
# iteration=2 epoch=9 Average Reward per episode: -47.201391340807966
# loading best result
# rollout iteration 3 with epsilon=87.50%...
# starting training on rollout information...
# iteration=3 epoch=0 Average Reward per episode: 79.1625604067812
# iteration=3 epoch=1 Average Reward per episode: 0.6268552177889966
# iteration=3 epoch=2 Average Reward per episode: -409.82137789381096
# iteration=3 epoch=3 Average Reward per episode: -213.15900326863562
# iteration=3 epoch=4 Average Reward per episode: -513.1656249383249
# iteration=3 epoch=5 Average Reward per episode: -687.8088866011819
# iteration=3 epoch=6 Average Reward per episode: -700.5591368766841
# iteration=3 epoch=7 Average Reward per episode: -681.6681896142748
# iteration=3 epoch=8 Average Reward per episode: -582.2331649277901
# iteration=3 epoch=9 Average Reward per episode: -591.5855532807716
# loading best result
# rollout iteration 4 with epsilon=83.33%...
# starting training on rollout information...
# iteration=4 epoch=0 Average Reward per episode: -21.740297054327318
# iteration=4 epoch=1 Average Reward per episode: 120.67833994235468
# iteration=4 epoch=2 Average Reward per episode: 37.7549417318076
# iteration=4 epoch=3 Average Reward per episode: 56.77768720404695
# iteration=4 epoch=4 Average Reward per episode: 1599.206463495744
# #################################
#  new best 1599.206463495744 saving Q...
# #################################
# iteration=4 epoch=5 Average Reward per episode: -321.77259012773754
# iteration=4 epoch=6 Average Reward per episode: -483.44404487450777
# iteration=4 epoch=7 Average Reward per episode: -432.7609068279019
# iteration=4 epoch=8 Average Reward per episode: -207.1740895300439
# iteration=4 epoch=9 Average Reward per episode: -369.19582529991453
# loading best result
# rollout iteration 5 with epsilon=79.17%...
# starting training on rollout information...
# iteration=5 epoch=0 Average Reward per episode: -47.12080369618805
# iteration=5 epoch=1 Average Reward per episode: -47.125164426518644
# iteration=5 epoch=2 Average Reward per episode: -47.12229434568836
# iteration=5 epoch=3 Average Reward per episode: -47.11805872000612
# iteration=5 epoch=4 Average Reward per episode: -47.11905187826436
# iteration=5 epoch=5 Average Reward per episode: -38.87723082490803
# iteration=5 epoch=6 Average Reward per episode: -39.081093643148385
# iteration=5 epoch=7 Average Reward per episode: -38.534163150503566
# iteration=5 epoch=8 Average Reward per episode: -43.89924737838545
# iteration=5 epoch=9 Average Reward per episode: -64.95251588800166
# loading best result
# rollout iteration 6 with epsilon=75.00%...
# starting training on rollout information...
# iteration=6 epoch=0 Average Reward per episode: -47.42974651457475
# iteration=6 epoch=1 Average Reward per episode: -47.10922101930124
# iteration=6 epoch=2 Average Reward per episode: -47.1095102208394
# iteration=6 epoch=3 Average Reward per episode: -47.10720787943059
# iteration=6 epoch=4 Average Reward per episode: -47.10233772060509
# iteration=6 epoch=5 Average Reward per episode: -47.11776450073156
# iteration=6 epoch=6 Average Reward per episode: -47.12614787081509
# iteration=6 epoch=7 Average Reward per episode: -47.122809443059495
# iteration=6 epoch=8 Average Reward per episode: -47.11569637084837
# iteration=6 epoch=9 Average Reward per episode: -47.116910318585965
# loading best result
# rollout iteration 7 with epsilon=70.83%...
# starting training on rollout information...
# iteration=7 epoch=0 Average Reward per episode: -428.9516845226967
# iteration=7 epoch=1 Average Reward per episode: -47.11143058536496
# iteration=11 epoch=7 Average Reward per episode: -47.43226126724769
# iteration=11 epoch=8 Average Reward per episode: -47.43346029201373
# iteration=11 epoch=9 Average Reward per episode: -47.42966387770272
# loading best result
# rollout iteration 12 with epsilon=50.00%...
# starting training on rollout information...
# iteration=12 epoch=0 Average Reward per episode: -47.43193044131293
# iteration=12 epoch=1 Average Reward per episode: -47.43393442554206
# iteration=12 epoch=2 Average Reward per episode: 58.536088666074235
# iteration=12 epoch=3 Average Reward per episode: -44.101800435024884
# iteration=12 epoch=4 Average Reward per episode: 42.043469372100205
# iteration=12 epoch=5 Average Reward per episode: 53.88444756151574
# iteration=12 epoch=6 Average Reward per episode: 53.74109704331285
# iteration=12 epoch=7 Average Reward per episode: -44.10192588664452
# iteration=12 epoch=8 Average Reward per episode: -47.43178668999385
# iteration=12 epoch=9 Average Reward per episode: -47.43429796438581
# loading best result
# rollout iteration 13 with epsilon=45.83%...
# starting training on rollout information...
# iteration=13 epoch=0 Average Reward per episode: -47.4340700326126
# iteration=13 epoch=1 Average Reward per episode: -47.43125205842688
# iteration=13 epoch=2 Average Reward per episode: -47.43525202492552
# iteration=13 epoch=3 Average Reward per episode: -47.43123764475929
# iteration=13 epoch=4 Average Reward per episode: -47.4331324690094
# iteration=13 epoch=5 Average Reward per episode: -47.433556058484776
# iteration=13 epoch=6 Average Reward per episode: -47.43350779807358
# iteration=13 epoch=7 Average Reward per episode: -47.42932434094651
# iteration=13 epoch=8 Average Reward per episode: -47.43182887463791
# iteration=13 epoch=9 Average Reward per episode: -47.43539436204441
# loading best result
# rollout iteration 14 with epsilon=41.67%...
# starting training on rollout information...
# iteration=14 epoch=0 Average Reward per episode: -47.43164220780959
# iteration=14 epoch=1 Average Reward per episode: -47.433509283003545
# iteration=14 epoch=2 Average Reward per episode: -47.43806392482877
# iteration=14 epoch=3 Average Reward per episode: -47.435998021536655
# iteration=14 epoch=4 Average Reward per episode: -47.43327084834639
# iteration=14 epoch=5 Average Reward per episode: -47.433227295011896
# iteration=14 epoch=6 Average Reward per episode: -47.0387435649973
# iteration=14 epoch=7 Average Reward per episode: -46.356309340605335
# iteration=14 epoch=8 Average Reward per episode: -46.35370803134004
# iteration=14 epoch=9 Average Reward per episode: -46.3539338868236
# loading best result
# rollout iteration 15 with epsilon=37.50%...
# starting training on rollout information...
# iteration=15 epoch=0 Average Reward per episode: 62.478837237956895
# iteration=15 epoch=1 Average Reward per episode: 64.2687117367962
# iteration=15 epoch=2 Average Reward per episode: 69.16753400371084
# iteration=15 epoch=3 Average Reward per episode: 66.28038052412123
# iteration=15 epoch=4 Average Reward per episode: -47.43042987885125
# iteration=15 epoch=5 Average Reward per episode: -47.435068949050724
# iteration=15 epoch=6 Average Reward per episode: -47.43245913730105
# iteration=15 epoch=7 Average Reward per episode: -47.43672425111568
# iteration=15 epoch=8 Average Reward per episode: -47.434743634086516
# iteration=15 epoch=9 Average Reward per episode: -47.4348510251422
# loading best result
# rollout iteration 16 with epsilon=33.33%...
# starting training on rollout information...
# iteration=16 epoch=0 Average Reward per episode: 65.33017854589828
# iteration=20 epoch=7 Average Reward per episode: -46.35424248684552
# iteration=20 epoch=8 Average Reward per episode: -47.434654768713855
# iteration=20 epoch=9 Average Reward per episode: -47.43366518835763
# loading best result
# rollout iteration 21 with epsilon=12.50%...
# starting training on rollout information...
# iteration=21 epoch=0 Average Reward per episode: 71.41595338227924
# iteration=21 epoch=1 Average Reward per episode: 75.86164907284612
# iteration=21 epoch=2 Average Reward per episode: 81.81850224107794
# iteration=21 epoch=3 Average Reward per episode: 90.40868176076305
# iteration=21 epoch=4 Average Reward per episode: 91.11946905310721
# iteration=21 epoch=5 Average Reward per episode: 91.49068210237898
# iteration=21 epoch=6 Average Reward per episode: 85.38762011911771
# iteration=21 epoch=7 Average Reward per episode: 79.94267601746364
# iteration=21 epoch=8 Average Reward per episode: 76.23610364354451
# iteration=21 epoch=9 Average Reward per episode: 71.19745800753317
# loading best result
# rollout iteration 22 with epsilon=8.33%...
# starting training on rollout information...
# iteration=22 epoch=0 Average Reward per episode: 71.70286713941145
# iteration=22 epoch=1 Average Reward per episode: 72.73609789975474
# iteration=22 epoch=2 Average Reward per episode: 79.38445844501656
# iteration=22 epoch=3 Average Reward per episode: 79.8893505058553
# iteration=22 epoch=4 Average Reward per episode: 79.89480055041281
# iteration=22 epoch=5 Average Reward per episode: 81.45022032200957
# iteration=22 epoch=6 Average Reward per episode: 80.25943862230962
# iteration=22 epoch=7 Average Reward per episode: 78.75257133199085
# iteration=22 epoch=8 Average Reward per episode: -47.43388846906771
# iteration=22 epoch=9 Average Reward per episode: -47.43266950114709
# loading best result
# rollout iteration 23 with epsilon=4.17%...
# starting training on rollout information...
# iteration=23 epoch=0 Average Reward per episode: 68.4449424680046
# iteration=23 epoch=1 Average Reward per episode: -38.53427933930819
# iteration=23 epoch=2 Average Reward per episode: 24.719731322293605
# iteration=23 epoch=3 Average Reward per episode: -41.422309703336744
# iteration=23 epoch=4 Average Reward per episode: -33.382463080731114
# iteration=23 epoch=5 Average Reward per episode: 59.82483970885513
# iteration=23 epoch=6 Average Reward per episode: 46.96205628310689
# iteration=23 epoch=7 Average Reward per episode: -47.43105690660724
# iteration=23 epoch=8 Average Reward per episode: -47.43528241248684
# iteration=23 epoch=9 Average Reward per episode: -47.43266935018085
# loading best result
# rollout iteration 24 with epsilon=0.00%...
# starting training on rollout information...
# iteration=24 epoch=0 Average Reward per episode: 82.93641860469451
# iteration=24 epoch=1 Average Reward per episode: 100.55523760336699
# iteration=24 epoch=2 Average Reward per episode: 121.39147350615477
# iteration=24 epoch=3 Average Reward per episode: 164.5493800114866
# iteration=24 epoch=4 Average Reward per episode: 297.8371960386943
# iteration=24 epoch=5 Average Reward per episode: 398.6682360810163
# iteration=24 epoch=6 Average Reward per episode: 423.61669637639034
# iteration=24 epoch=7 Average Reward per episode: 375.3800594256829
# iteration=24 epoch=8 Average Reward per episode: 294.94027591524883
# iteration=24 epoch=9 Average Reward per episode: 20.300716711235538
# loading best result
# loading best result

# %%
# # reward_function =  lambda self: np.exp(-(self.th%(2*np.pi)-np.pi)**2/(2*(np.pi/7)**2))
# # reward_function =  lambda self: (np.cos(self.th - target_angle)+1)**2  - np.cos(self.th-(np.pi+target_angle)) - 0.01*(self.omega)**2 - 0.01*(self.u)**2
# # reward_function =  lambda self: ((np.cos(self.th-target_angle)+1.5)**2 - 0.25) + 0.00125*(((np.cos(self.th)+1)/2)*(self.omega)**2) - 0.0075*((self.u)**2) - 0.0025*((self.omega)**2)

# # Washing machine (Qfunction2)
# # reward_function = lambda self: np.exp(-(self.th % (2 * np.pi) - np.pi) ** 2 / (2 * (np.pi / 7) ** 2)) + (1.0 if np.abs(self.th % (2 * np.pi) - np.pi) < np.pi / 2 else 0.0) - 0.001 * self.u ** 2
# # stuck at u=3
# # reward_function = lambda self: ((np.cos(self.th-target_angle)+1.6)** 2 - 0.25) - 0.0025*(self.omega)** 2 - 0.0075*(self.u)**2

# # reward_function = lambda self: np.exp(-(self.th % (2 * np.pi) - np.pi) ** 2 / (2 * (np.pi / 7) ** 2)) + (1.0 if np.abs(self.th % (2 * np.pi) - np.pi) < np.pi / 2 else -0.5) - 0.001 * self.u ** 2

# # Yann best
# reward_function =  lambda self: ((np.cos(self.th-target_angle)+1.5)**2 - 0.25) + 0.00125*(((np.cos(self.th)+1)/2)*(self.omega)**2) - 0.01*((self.u)**2)

# %%
u,theta,omega = show(Q,env)

# %%
target_angle = np.pi # target set to be balanced on top

# Create a figure with three subplots
fig, axs = plt.subplots(1, 3, figsize=(12, 4))

# Plot theta
axs[0].plot([i*env.dt for i in range(max_episode_steps)], theta, '-')
axs[0].set_title('Theta')
axs[0].set_xlabel('Time (s)')
axs[0].set_ylabel('Angle (Rad)')
axs[0].axhline(y=target_angle, color='r', linestyle='-')
axs[0].axhline(y=-target_angle, color='r', linestyle='-')
axs[0].grid(True)

# Plot u
axs[1].plot([i*env.dt for i in range(max_episode_steps)], u, '.')
axs[1].set_title('u')
axs[1].set_xlabel('Time (s)')
axs[1].set_ylabel('Input voltage (V)')
axs[1].grid(True)

# Plot omega
axs[2].plot([i*env.dt for i in range(max_episode_steps)], omega, '.')
axs[2].set_title('Omega')
axs[2].set_xlabel('Time (s)')
axs[2].set_ylabel('Angular velocity (rad/s)')
axs[2].grid(True)

# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Save Q to a file
date = datetime.datetime.now().strftime("%d_%H_%M")
torch.save(Q.state_dict(), 'Qfunction' + date + '.pt')

# %%
eval_Q(Q,env)
# Out:
# 1598.6194816058062

# %%
Rewards = [eval_Q(Q,env) for i in range(100)]
plt.plot(Rewards,'.')
plt.title(f'mean={np.mean(Rewards)}')
plt.xlabel('instance')
plt.ylabel('Reward per episode')
plt.show()

# %%
Rewards = [eval_Q(Q,env) for i in range(100)]
plt.plot(Rewards,'.')
plt.title(f'mean={np.mean(Rewards)}')
plt.xlabel('instance')
plt.ylabel('Reward per episode')
plt.ylim(np.min(Rewards)-2.5, np.max(Rewards)+2.5)
plt.axhline(y=np.mean(Rewards), color='r', linestyle='-')
plt.grid(True)
plt.show()

# %%
Q
# Out:
# Qfunction(
#   (lay1): Linear(in_features=3, out_features=40, bias=True)
#   (F1): Tanh()
#   (lay2): Linear(in_features=40, out_features=15, bias=True)
# )

# %%
env.action_space.n
# Out:
# 15
