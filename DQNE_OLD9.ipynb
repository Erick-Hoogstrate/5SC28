# %%
import sys
sys.path.append('gym-unbalanced-disk/gym_unbalanced_disk/')
from torch import nn
import torch, gym, gym_unbalanced_disk, time, gym.wrappers
import numpy as np
from matplotlib import pyplot as plt
from copy import deepcopy
import os
import datetime

# %% [markdown]
# # QFUNCTION NOG AANPASSEN

# %%
class Qfunction(nn.Module):
    def __init__(self, env):
        super(Qfunction,self).__init__()
        self.lay1 = nn.Linear(env.observation_space.shape[0], 40)
        self.F1 =  nn.Tanh() #a)
        self.lay2 = nn.Linear(40,env.action_space.n)
    
    def forward(self, obs):
        return self.lay2(self.F1(self.lay1(obs)))

# %%
def show(Q,env):
    u = []
    theta = []
    omega = []
    with torch.no_grad():
        #you can use Qfun(obs) as a shorthand for the q function.
        Qfun = lambda x: Q(torch.tensor(x[None,:],dtype=torch.float32))[0].numpy() #convert x to torch.tensor -> put in the Q function -> back to numpy
        try:
            obs = env.reset() #b)
            env.render() #b)
            time.sleep(10) # give time to open window
            while True: #b)
                action = np.argmax(Qfun(obs)) #b)
                obs, reward, done, info = env.step(action) #b)
                time.sleep(1/60) #b)
                env.render() #b)
                u.append(env.u)
                theta.append(env.th)
                omega.append(env.omega)
                if done: #b)
                    time.sleep(0.5)  #b)
                    break  #b)
        finally: #this will always run even when an error occurs
            env.close()
            return u,theta,omega

# %%
def rollout(Q, env, epsilon=0.1, N_rollout=10_000): 
    #save the following (use .append)
    Start_state = [] #hold an array of (x_t)
    Actions = [] #hold an array of (u_t)
    Rewards = [] #hold an array of (r_{t+1})
    End_state = [] #hold an array of (x_{t+1})
    Terminal = [] #hold an array of (terminal_{t+1})
    # Qfun( a numpy array of the obs) -> a numpy array of Q values
    Qfun = lambda x: Q(torch.tensor(x[None,:],dtype=torch.float32))[0].numpy() 
    with torch.no_grad():
        
        obs = env.reset() #c)
        for i in range(N_rollout): #c)
            if np.random.uniform()>epsilon: #c)
                Qnow = Qfun(obs) #c)
                action = np.argmax(Qnow) #c)
            else: #c)
                action = env.action_space.sample() #c)
            Start_state.append(obs) #c)
            Actions.append(action) #c)

            obs_next, reward, done, info = env.step(action) #c)
            terminal = done and not info.get('TimeLimit.truncated', False) #c)

            Terminal.append(terminal) #c)
            Rewards.append(reward) #c)
            End_state.append(obs_next) #c)

            if done: #c)
                obs = env.reset() #c)
            else: #c)
                obs = obs_next #c)
                
    #error checking:
    assert len(Start_state)==len(Actions)==len(Rewards)==len(End_state)==len(Terminal), f'error in lengths: {len(Start_state)}=={len(Actions)}=={len(Rewards)}=={len(End_state)}=={len(Dones)}'
    return np.array(Start_state), np.array(Actions), np.array(Rewards), np.array(End_state), np.array(Terminal).astype(int)

# %%
def eval_Q(Q,env):
    with torch.no_grad():
        Qfun = lambda x: Q(torch.tensor(x[None,:],dtype=torch.float32))[0].numpy()
        rewards_acc = 0 #d)
        obs = env.reset() #d)
        while True: #d)
            action = np.argmax(Qfun(obs)) #d)
            obs, reward, done, info = env.step(action) #d)
            rewards_acc += reward #d)
            if done: #d)
                return rewards_acc #d)

# %%
def DQN_rollout(Q, optimizer, env, gamma=0.98, use_target_net=False, N_iterations=21, N_rollout=20000, \
                N_epochs=10, batch_size=32, N_evals=10, target_net_update_feq=100):
    best = -float('inf')
    torch.save(Q.state_dict(),'Q-checkpoint')
    try:
        for iteration in range(N_iterations):
            epsilon = 1.0 - iteration/(N_iterations-1) #e=) 1.
            print(f'rollout iteration {iteration} with epsilon={epsilon:.2%}...')
            
            #2. rollout
            Start_state, Actions, Rewards, End_state, Dones = rollout(Q, env, epsilon=epsilon, N_rollout=N_rollout) #e) 2.
            
            #Data conversion, no changes required
            convert = lambda x: [torch.tensor(xi,dtype=torch.float32) for xi in x]
            Start_state, Rewards, End_state, Dones = convert([Start_state, Rewards, End_state, Dones])
            Actions = Actions.astype(int)

            print('starting training on rollout information...')
            t = 0
            for epoch in range(N_epochs): 
                for i in range(batch_size,len(Start_state)+1,batch_size): 
                    if t%target_net_update_feq==0:
                        Qtarget = deepcopy(Q) #g)
                        pass
                    t += 1
                    
                    Start_state_batch, Actions_batch, Rewards_batch, End_state_batch, Dones_batch = [d[i-batch_size:i] for d in [Start_state, Actions, Rewards, End_state, Dones]] #e=) 3.
                    
                    with torch.no_grad(): #3.
                        if use_target_net:
                            maxQ = torch.max(Qtarget(End_state_batch),dim=1)[0] #g)
                        else:
                            maxQ = torch.max(Q(End_state_batch),dim=1)[0] #e=) 3.
                    
                    action_index = np.stack((np.arange(batch_size),Actions_batch),axis=0)
                    Qnow = Q(Start_state_batch)[action_index] #Q(x_t,u_t) is given
                    
                    Loss = torch.mean((Rewards_batch + gamma*maxQ*(1-Dones_batch) - Qnow)**2) #e) 3.
                    optimizer.zero_grad() #e) 3.
                    Loss.backward() #e) 3.
                    optimizer.step() #e) 3.
                
                score = np.mean([eval_Q(Q,env) for i in range(N_evals)]) #e=) 3.
                
                print(f'iteration={iteration} epoch={epoch} Average Reward per episode:',score)
                if score>best:
                    best = score
                    print('################################# \n new best',best,'saving Q... \n#################################')
                    torch.save(Q.state_dict(),'Q-checkpoint3')
            
            print('loading best result')
            Q.load_state_dict(torch.load('Q-checkpoint3'))
    finally: #this will always run even when using the a KeyBoard Interrupt. 
        print('loading best result')
        Q.load_state_dict(torch.load('Q-checkpoint3'))

# %%
target_angle = np.pi # target set to be balanced on top

# %%
angle_reward = lambda self: ((np.cos(self.th-target_angle)+1.5)**2 - 0.25)
correctVelocity_reward = lambda self: 0.00250*(((np.cos(self.th)+1)/2)*(self.omega)**2)
voltage_penalty = lambda self: -0.005*((self.u)**2)
incorrectAngle_penalty = lambda self: -0.05*np.abs(self.th-target_angle)

reward_function = lambda self: angle_reward(self) + correctVelocity_reward(self) + voltage_penalty(self) + incorrectAngle_penalty(self)

max_episode_steps = 250
gamma = 0.98
batch_size = 32
N_iterations = 15
N_rollout = 10000
N_epochs = 5
N_evals = 5
lr = 0.0005

# %%
env = gym.make('unbalanced-disk-sincos-v0', dt=0.025, umax=3.)
env = gym.wrappers.time_limit.TimeLimit(env,max_episode_steps=max_episode_steps)
env.change_reward_function(reward_function)
# Out:
# Running from folder

# %%
env.set_discrete_values(discrete_size = 9, minmax = 3.0, div = 2.5, rnd = 2)
# env.set_discrete_values_manual([-3.0, -1.5, -0.75, -0.5, -0.25, -0.15, -0.1, 0, 0.1, 0.15, 0.25, 0.5, 0.75, 1.5, 3.0])
# Out:
# Discrete value set changed to [-3.0, -1.2, -0.48, -0.19, 0, 0.19, 0.48, 1.2, 3.0]

# %%
assert isinstance(env.action_space,gym.spaces.Discrete), 'action space requires to be discrete'
Q = Qfunction(env)
optimizer = torch.optim.Adam(Q.parameters(),lr=lr) #low learning rate
DQN_rollout(Q, optimizer, env, use_target_net=True, gamma=gamma, N_iterations=N_iterations, \
            N_rollout=N_rollout, N_epochs=N_epochs, N_evals=N_evals)
# Out:
# rollout iteration 0 with epsilon=100.00%...
# starting training on rollout information...
# iteration=0 epoch=0 Average Reward per episode: -24.15203094132779
# #################################
#  new best -24.15203094132779 saving Q...
# #################################
# iteration=0 epoch=1 Average Reward per episode: -136.9402046098679
# iteration=0 epoch=2 Average Reward per episode: -194.66189991046463
# iteration=0 epoch=3 Average Reward per episode: -193.1356993467689
# iteration=0 epoch=4 Average Reward per episode: -193.77900575298372
# loading best result
# rollout iteration 1 with epsilon=92.86%...
# starting training on rollout information...
# iteration=1 epoch=0 Average Reward per episode: -181.5107498212147
# iteration=1 epoch=1 Average Reward per episode: -194.376782465296
# iteration=1 epoch=2 Average Reward per episode: -200.25099982385956
# iteration=1 epoch=3 Average Reward per episode: 177.17695256158157
# #################################
#  new best 177.17695256158157 saving Q...
# #################################
# iteration=1 epoch=4 Average Reward per episode: 413.6299682015448
# #################################
#  new best 413.6299682015448 saving Q...
# #################################
# loading best result
# rollout iteration 2 with epsilon=85.71%...
# starting training on rollout information...
# iteration=2 epoch=0 Average Reward per episode: 265.28477783264105
# iteration=2 epoch=1 Average Reward per episode: 264.5360871845117
# iteration=2 epoch=2 Average Reward per episode: 390.6691625286869
# iteration=2 epoch=3 Average Reward per episode: 267.66522164054874
# iteration=2 epoch=4 Average Reward per episode: 323.0362572795102
# loading best result
# rollout iteration 3 with epsilon=78.57%...
# starting training on rollout information...
# iteration=3 epoch=0 Average Reward per episode: -36.898718049458964
# iteration=3 epoch=1 Average Reward per episode: 284.59852300934483
# iteration=3 epoch=2 Average Reward per episode: -11.023925576133735
# iteration=3 epoch=3 Average Reward per episode: -26.206292817845245
# iteration=3 epoch=4 Average Reward per episode: -36.885238976436895
# loading best result
# rollout iteration 4 with epsilon=71.43%...
# starting training on rollout information...
# iteration=4 epoch=0 Average Reward per episode: -39.25594091439281
# iteration=4 epoch=1 Average Reward per episode: -34.61534487537356
# iteration=4 epoch=2 Average Reward per episode: -33.01357084414205
# iteration=4 epoch=3 Average Reward per episode: -36.90710539467455
# iteration=4 epoch=4 Average Reward per episode: -39.272525886856705
# loading best result
# rollout iteration 5 with epsilon=64.29%...
# starting training on rollout information...
# iteration=5 epoch=0 Average Reward per episode: 193.8850064064445
# iteration=5 epoch=1 Average Reward per episode: -38.278288633358756
# iteration=5 epoch=2 Average Reward per episode: -39.268286566519535
# iteration=5 epoch=3 Average Reward per episode: -39.263573346387815
# iteration=5 epoch=4 Average Reward per episode: -39.26620422159313
# loading best result
# rollout iteration 6 with epsilon=57.14%...
# starting training on rollout information...
# iteration=6 epoch=0 Average Reward per episode: -33.484456740289964
# iteration=6 epoch=1 Average Reward per episode: -39.26145003555462
# iteration=6 epoch=2 Average Reward per episode: -39.270017409076786
# iteration=6 epoch=3 Average Reward per episode: -39.26177243211966
# iteration=6 epoch=4 Average Reward per episode: -39.47530846047973
# loading best result
# rollout iteration 7 with epsilon=50.00%...
# starting training on rollout information...
# iteration=7 epoch=0 Average Reward per episode: -14.957154510742646
# iteration=7 epoch=1 Average Reward per episode: -37.12177485908635
# iteration=7 epoch=2 Average Reward per episode: -39.21906812762198
# iteration=7 epoch=3 Average Reward per episode: -39.261756073873315
# iteration=7 epoch=4 Average Reward per episode: -39.265586473475686
# loading best result
# rollout iteration 8 with epsilon=42.86%...
# starting training on rollout information...
# iteration=8 epoch=0 Average Reward per episode: 89.54968817410187
# iteration=8 epoch=1 Average Reward per episode: -39.269497782469024
# iteration=8 epoch=2 Average Reward per episode: -39.26239111402411
# iteration=8 epoch=3 Average Reward per episode: -39.27130795782286
# iteration=8 epoch=4 Average Reward per episode: -39.26615771965206
# loading best result
# rollout iteration 9 with epsilon=35.71%...
# starting training on rollout information...
# iteration=9 epoch=0 Average Reward per episode: -65.85058239158491
# iteration=9 epoch=1 Average Reward per episode: 88.08574176086229
# iteration=9 epoch=2 Average Reward per episode: -37.84257765792425
# iteration=9 epoch=3 Average Reward per episode: -39.27290157057577
# iteration=9 epoch=4 Average Reward per episode: -39.267409335635264
# loading best result
# rollout iteration 10 with epsilon=28.57%...
# starting training on rollout information...
# iteration=10 epoch=0 Average Reward per episode: 68.27768752000989
# iteration=10 epoch=1 Average Reward per episode: 91.20712558683167
# iteration=10 epoch=2 Average Reward per episode: -34.66732470374169
# iteration=10 epoch=3 Average Reward per episode: 115.62388027232774
# iteration=10 epoch=4 Average Reward per episode: -39.26901522226782
# loading best result
# rollout iteration 11 with epsilon=21.43%...
# starting training on rollout information...
# iteration=11 epoch=0 Average Reward per episode: -73.45781927714597
# iteration=11 epoch=1 Average Reward per episode: 159.06782799849958
# iteration=11 epoch=2 Average Reward per episode: 82.46232787085027
# iteration=11 epoch=3 Average Reward per episode: -34.2848477438576
# iteration=11 epoch=4 Average Reward per episode: -38.303635548509924
# loading best result
# rollout iteration 12 with epsilon=14.29%...
# starting training on rollout information...
# iteration=12 epoch=0 Average Reward per episode: -73.26931065426011
# iteration=12 epoch=1 Average Reward per episode: 162.89379333680077
# iteration=12 epoch=2 Average Reward per episode: -36.013684998779446
# iteration=12 epoch=3 Average Reward per episode: -35.99870528223875
# iteration=12 epoch=4 Average Reward per episode: -36.01499400651767
# loading best result
# rollout iteration 13 with epsilon=7.14%...
# starting training on rollout information...
# iteration=13 epoch=0 Average Reward per episode: -78.01997177072195
# iteration=13 epoch=1 Average Reward per episode: 184.76136466481677
# iteration=13 epoch=2 Average Reward per episode: 268.24670744719344
# iteration=13 epoch=3 Average Reward per episode: -36.00268746170967
# iteration=13 epoch=4 Average Reward per episode: -35.992286368859524
# loading best result
# rollout iteration 14 with epsilon=0.00%...
# starting training on rollout information...
# iteration=14 epoch=0 Average Reward per episode: -29.857907530808404
# iteration=14 epoch=1 Average Reward per episode: 111.76831256604154
# iteration=14 epoch=2 Average Reward per episode: 320.01910625591415
# iteration=14 epoch=3 Average Reward per episode: 206.79148959635896
# iteration=14 epoch=4 Average Reward per episode: 119.26006982901932
# loading best result
# loading best result

# %%
# # reward_function =  lambda self: np.exp(-(self.th%(2*np.pi)-np.pi)**2/(2*(np.pi/7)**2))
# # reward_function =  lambda self: (np.cos(self.th - target_angle)+1)**2  - np.cos(self.th-(np.pi+target_angle)) - 0.01*(self.omega)**2 - 0.01*(self.u)**2
# # reward_function =  lambda self: ((np.cos(self.th-target_angle)+1.5)**2 - 0.25) + 0.00125*(((np.cos(self.th)+1)/2)*(self.omega)**2) - 0.0075*((self.u)**2) - 0.0025*((self.omega)**2)

# # Washing machine (Qfunction2)
# # reward_function = lambda self: np.exp(-(self.th % (2 * np.pi) - np.pi) ** 2 / (2 * (np.pi / 7) ** 2)) + (1.0 if np.abs(self.th % (2 * np.pi) - np.pi) < np.pi / 2 else 0.0) - 0.001 * self.u ** 2
# # stuck at u=3
# # reward_function = lambda self: ((np.cos(self.th-target_angle)+1.6)** 2 - 0.25) - 0.0025*(self.omega)** 2 - 0.0075*(self.u)**2

# # reward_function = lambda self: np.exp(-(self.th % (2 * np.pi) - np.pi) ** 2 / (2 * (np.pi / 7) ** 2)) + (1.0 if np.abs(self.th % (2 * np.pi) - np.pi) < np.pi / 2 else -0.5) - 0.001 * self.u ** 2

# # Yann best
# reward_function =  lambda self: ((np.cos(self.th-target_angle)+1.5)**2 - 0.25) + 0.00125*(((np.cos(self.th)+1)/2)*(self.omega)**2) - 0.01*((self.u)**2)

# %%
u,theta,omega = show(Q,env)
# Out:
# pygame 2.4.0 (SDL 2.26.4, Python 3.8.16)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
target_angle = np.pi # target set to be balanced on top

# Create a figure with three subplots
fig, axs = plt.subplots(1, 3, figsize=(12, 4))

# Plot theta
axs[0].plot([i*env.dt for i in range(max_episode_steps)], theta, '.')
axs[0].set_title('Theta')
axs[0].set_xlabel('Time (s)')
axs[0].set_ylabel('Angle (Rad)')
axs[0].axhline(y=target_angle, color='r', linestyle='-')
axs[0].axhline(y=-target_angle, color='r', linestyle='-')
axs[0].grid(True)

# Plot u
axs[1].plot([i*env.dt for i in range(max_episode_steps)], u, '.')
axs[1].set_title('u')
axs[1].set_xlabel('Time (s)')
axs[1].set_ylabel('Input voltage (V)')
axs[1].grid(True)

# Plot omega
axs[2].plot([i*env.dt for i in range(max_episode_steps)], omega, '.')
axs[2].set_title('Omega')
axs[2].set_xlabel('Time (s)')
axs[2].set_ylabel('Angular velocity (rad/s)')
axs[2].grid(True)

# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Save Q to a file
date = datetime.datetime.now().strftime("%d_%H_%M")
torch.save(Q.state_dict(), 'Qfunction' + date + '.pt')

# %%
eval_Q(Q,env)
# Out:
# 403.04269817445305

# %%
Rewards = [eval_Q(Q,env) for i in range(100)]
plt.plot(Rewards,'-')
plt.title(f'mean={np.mean(Rewards)}')
plt.xlabel('instance')
plt.ylabel('Reward per episode')
plt.show()

# %%
Rewards = [eval_Q(Q,env) for i in range(100)]
plt.plot(Rewards,'-')
plt.title(f'mean={np.mean(Rewards)}')
plt.xlabel('instance')
plt.ylabel('Reward per episode')
plt.ylim(np.min(Rewards)-2.5, np.max(Rewards)+2.5)
plt.axhline(y=np.mean(Rewards), color='r', linestyle='-')
plt.grid(True)
plt.show()

# %%
Q
# Out:
# Qfunction(
#   (lay1): Linear(in_features=3, out_features=40, bias=True)
#   (F1): Tanh()
#   (lay2): Linear(in_features=40, out_features=9, bias=True)
# )

# %%
env.action_space.n
# Out:
# 9
